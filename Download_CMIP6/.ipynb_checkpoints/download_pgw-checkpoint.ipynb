# %%
import intake
import os

# %%
url = "https://raw.githubusercontent.com/NCAR/intake-esm-datastore/master/catalogs/pangeo-cmip6.json"
# open the catalog
dataframe = intake.open_esm_datastore(url)
dataframe.df.columns
df = dataframe.df
# Out:
# /Users/doan/anaconda3/envs/intake_esm/lib/python3.12/site-packages/fastprogress/fastprogress.py:107: UserWarning: Couldn't import ipywidgets properly, progress bar will use console behavior
#   warn("Couldn't import ipywidgets properly, progress bar will use console behavior")

# %%
import re
def natural_sort(l): 
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)', key)]
    return sorted(l, key=alphanum_key)

# %%
for sid in [ 'EC-Earth3', 'MIROC6',  'MRI-ESM2-0', 'ACCESS-CM2', 'IPSL-CM6A-LR', 'MPI-ESM1-2-HR'][:1]:
    for exp in ['historical','ssp585', 'ssp126', 'ssp370','ssp245'][:]:
            for var in ['tas','ta','ua','va','hur','zg','ts'][:]:
                # seach all files with information given above
                models = dataframe.search(experiment_id=exp,
                                          table_id='Amon',
                                          variable_id=var,
                                          source_id = sid,
                                          #institution_id=ins,
                                          #member_id=mem
                                          )  
                # then one might get several files with the same conditions
                # r1: Realization (initial condition run)
                # i1: Initialization method
                # p1: Physical parameters
                # f1: External forcings

                print(var, exp, sid,  len(models.df))

                # if no files exist then print out error
                if len(models.df) == 0: print('*** \n Erorrrr \n')

                # sort the possible files
                ml = natural_sort(models.df.member_id.values)

                # get the first one only then seach again
                mem = ml[0]
                model_s = dataframe.search(experiment_id=exp,
                                          table_id='Amon',
                                          variable_id=var,
                                          source_id = sid,
                                          #institution_id=ins,
                                          member_id=mem
                                          )                  

                # if no files exist then print out error
                if len(model_s.df) == 0: print('*** \n Erorrrr \n')

                print(mem)

                if len(model_s.df) > 0:
                    print('Download')
                    
                    if True:
                        
                        try:
                        
                            datasets = model_s.to_dataset_dict(zarr_kwargs={'consolidated': True, "decode_times": True, "use_cftime": True })
                            #datasets = models.to_dataset_dict(xarray_open_kwargs={"consolidated": True, "decode_times": True, "use_cftime": True})
                            
                            for k, v in datasets.items():
                                odir = 'Download_s8/'+sid+'/'+exp+'/'
                                if not os.path.exists(odir): os.makedirs(odir)
                                ofile = odir + var + '_'+ k + '_'+mem+'.nc'
                                print('write to ',ofile)
                                v.to_netcdf(ofile)
                        except:
                            print('fail')
# Out:
# tas historical EC-Earth3 73
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/historical/tas_CMIP.EC-Earth-Consortium.EC-Earth3.historical.Amon.gr_r1i1p1f1.nc
# ta historical EC-Earth3 71
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/historical/ta_CMIP.EC-Earth-Consortium.EC-Earth3.historical.Amon.gr_r1i1p1f1.nc
# ua historical EC-Earth3 72
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/historical/ua_CMIP.EC-Earth-Consortium.EC-Earth3.historical.Amon.gr_r1i1p1f1.nc
# fail
# va historical EC-Earth3 72
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/historical/va_CMIP.EC-Earth-Consortium.EC-Earth3.historical.Amon.gr_r1i1p1f1.nc
# hur historical EC-Earth3 21
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/historical/hur_CMIP.EC-Earth-Consortium.EC-Earth3.historical.Amon.gr_r1i1p1f1.nc
# zg historical EC-Earth3 71
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/historical/zg_CMIP.EC-Earth-Consortium.EC-Earth3.historical.Amon.gr_r1i1p1f1.nc
# ts historical EC-Earth3 23
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/historical/ts_CMIP.EC-Earth-Consortium.EC-Earth3.historical.Amon.gr_r1i1p1f1.nc
# tas ssp585 EC-Earth3 58
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/ssp585/tas_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.Amon.gr_r1i1p1f1.nc
# ta ssp585 EC-Earth3 58
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/ssp585/ta_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.Amon.gr_r1i1p1f1.nc
# ua ssp585 EC-Earth3 58
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/ssp585/ua_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.Amon.gr_r1i1p1f1.nc
# va ssp585 EC-Earth3 57
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/ssp585/va_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.Amon.gr_r1i1p1f1.nc
# hur ssp585 EC-Earth3 8
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/ssp585/hur_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.Amon.gr_r1i1p1f1.nc
# zg ssp585 EC-Earth3 58
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/ssp585/zg_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.Amon.gr_r1i1p1f1.nc
# ts ssp585 EC-Earth3 8
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/ssp585/ts_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp585.Amon.gr_r1i1p1f1.nc
# tas ssp126 EC-Earth3 57
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/ssp126/tas_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126.Amon.gr_r1i1p1f1.nc
# ta ssp126 EC-Earth3 7
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/ssp126/ta_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126.Amon.gr_r1i1p1f1.nc
# ua ssp126 EC-Earth3 7
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/ssp126/ua_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126.Amon.gr_r1i1p1f1.nc
# va ssp126 EC-Earth3 7
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/ssp126/va_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126.Amon.gr_r1i1p1f1.nc
# hur ssp126 EC-Earth3 7
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/ssp126/hur_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126.Amon.gr_r1i1p1f1.nc
# zg ssp126 EC-Earth3 7
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/ssp126/zg_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126.Amon.gr_r1i1p1f1.nc
# ts ssp126 EC-Earth3 7
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/ssp126/ts_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp126.Amon.gr_r1i1p1f1.nc
# tas ssp370 EC-Earth3 57
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/ssp370/tas_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp370.Amon.gr_r1i1p1f1.nc
# ta ssp370 EC-Earth3 56
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/ssp370/ta_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp370.Amon.gr_r1i1p1f1.nc
# ua ssp370 EC-Earth3 56
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/ssp370/ua_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp370.Amon.gr_r1i1p1f1.nc
# va ssp370 EC-Earth3 56
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/ssp370/va_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp370.Amon.gr_r1i1p1f1.nc
# hur ssp370 EC-Earth3 7
# r1i1p1f1
# Download
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# write to  Download_s8/EC-Earth3/ssp370/hur_ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp370.Amon.gr_r1i1p1f1.nc
