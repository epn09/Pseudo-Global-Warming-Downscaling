# %% [markdown]
# # RUN TEST SIMULATION
#
# ## Control run
#
# * Prepare run directory: wps, wrf
#
# * Namelist setting
#
# * Run geogrid, ungrib, metgrid, real and wrf

# %%
import xarray as xr
import pandas as pd
import numpy as np
import os, sys, glob

# %% [markdown]
# ### Preparing run directory

# %%
wpsdir = "/Volumes/work/WRF_program/WRF_install/WPS/"
wrfdir = "/Volumes/work/WRF_program/WRF_install/WRF_serial/"
geogdir = "/Volumes/work/WRF_program/WPS_GEOG"
renaldir = "/Volumes/work/WRF_program/era5/"
namelist_wps_path = "/Volumes/work/WRF_program/namelist/namelist.wps"
namelist_input_path = "/Volumes/work/WRF_program/namelist/namelist.input"

run_dir = "control"

# %%
st_date, en_date = "2023-01-01 00", "2023-01-01 18"
lat, lon = 35, 139

# %%
import shutil

for idir in ['geogrid', 'ungrib', 'metgrid']: 
    # Copy the directory tree, allowing existing destination directory
    shutil.copytree(wpsdir+'/'+idir, run_dir+'/'+idir, dirs_exist_ok=True)
    shutil.copy2(wpsdir+'/'+idir+'.exe', run_dir+'/'+idir+'.exe')    

shutil.copy2(wpsdir+'/link_grib.csh', run_dir)
# Out:
# 'control/link_grib.csh'

# %%
# %ls control/
# Out:
# BROADBAND_CLOUD_GODDARD.bin        ishmael-gamma-tab.bin
# CAM_ABS_DATA                       ishmael-qi-qc.bin
# CAM_AEROPT_DATA                    ishmael-qi-qr.bin
# CAMtr_volume_mixing_ratio          kernels.asc_s_0_03_0_9
# CAMtr_volume_mixing_ratio.A1B      kernels_z.asc
# CAMtr_volume_mixing_ratio.A2       link_grib.csh*
# CAMtr_volume_mixing_ratio.RCP4.5   masses.asc
# CAMtr_volume_mixing_ratio.RCP6     met_em.d01.2023-01-01_00:00:00.nc
# CAMtr_volume_mixing_ratio.RCP8.5   met_em.d01.2023-01-01_03:00:00.nc
# CAMtr_volume_mixing_ratio.SSP119   met_em.d01.2023-01-01_06:00:00.nc
# CAMtr_volume_mixing_ratio.SSP126   met_em.d01.2023-01-01_09:00:00.nc
# CAMtr_volume_mixing_ratio.SSP245   met_em.d01.2023-01-01_12:00:00.nc
# CAMtr_volume_mixing_ratio.SSP370   met_em.d01.2023-01-01_15:00:00.nc
# CAMtr_volume_mixing_ratio.SSP585   met_em.d01.2023-01-01_18:00:00.nc
# CCN_ACTIVATE.BIN                   met_em.d02.2023-01-01_00:00:00.nc
# CLM_ALB_ICE_DFS_DATA               met_em.d02.2023-01-01_03:00:00.nc
# CLM_ALB_ICE_DRC_DATA               met_em.d02.2023-01-01_06:00:00.nc
# CLM_ASM_ICE_DFS_DATA               met_em.d02.2023-01-01_09:00:00.nc
# CLM_ASM_ICE_DRC_DATA               met_em.d02.2023-01-01_12:00:00.nc
# CLM_DRDSDT0_DATA                   met_em.d02.2023-01-01_15:00:00.nc
# CLM_EXT_ICE_DFS_DATA               met_em.d02.2023-01-01_18:00:00.nc
# CLM_EXT_ICE_DRC_DATA               metgrid/
# CLM_KAPPA_DATA                     metgrid.exe*
# CLM_TAU_DATA                       metgrid.log
# ERA5A:2023-01-01_00                namelist.input
# ERA5A:2023-01-01_03                namelist.output
# ERA5A:2023-01-01_06                namelist.wps
# ERA5A:2023-01-01_09                ndown.exe*
# ERA5A:2023-01-01_12                ozone.formatted
# ERA5A:2023-01-01_15                ozone_lat.formatted
# ERA5A:2023-01-01_18                ozone_plev.formatted
# ERA5S:2023-01-01_00                p3_lookupTable_1.dat-v5.4_2momI
# ERA5S:2023-01-01_03                p3_lookupTable_1.dat-v5.4_3momI
# ERA5S:2023-01-01_06                p3_lookupTable_2.dat-v5.3
# ERA5S:2023-01-01_09                qr_acr_qg_V4.dat
# ERA5S:2023-01-01_12                qr_acr_qsV2.dat
# ERA5S:2023-01-01_15                real.exe*
# ERA5S:2023-01-01_18                tc.exe*
# ETAMPNEW_DATA                      termvels.asc
# ETAMPNEW_DATA.expanded_rain*       tr49t67
# ETAMPNEW_DATA.expanded_rain_DBL    tr49t85
# ETAMPNEW_DATA_DBL                  tr67t85
# GENPARM.TBL                        ungrib/
# GRIBFILE.AAA@                      ungrib.exe*
# HLC.TBL                            ungrib.log
# LANDUSE.TBL                        wind-turbine-1.tbl
# MPTABLE.TBL                        wrf.exe*
# NUL                                wrfbdy_d01
# README.namelist                    wrfinput_d01
# README.physics_files               wrfinput_d02
# README.rasm_diag                   wrfout_d01_2023-01-01_00:00:00
# README.tslist                      wrfout_d01_2023-01-01_01:00:00
# RRTMG_LW_DATA                      wrfout_d01_2023-01-01_02:00:00
# RRTMG_LW_DATA_DBL                  wrfout_d01_2023-01-01_03:00:00
# RRTMG_SW_DATA                      wrfout_d01_2023-01-01_04:00:00
# RRTMG_SW_DATA_DBL                  wrfout_d01_2023-01-01_05:00:00
# RRTM_DATA                          wrfout_d01_2023-01-01_06:00:00
# RRTM_DATA_DBL                      wrfout_d01_2023-01-01_07:00:00
# SOILPARM.TBL                       wrfout_d01_2023-01-01_08:00:00
# SOILPARM.TBL_Kishne_2017           wrfout_d01_2023-01-01_09:00:00
# STOCHPERT.TBL                      wrfout_d01_2023-01-01_10:00:00
# URBPARM.TBL                        wrfout_d01_2023-01-01_11:00:00
# URBPARM_LCZ.TBL                    wrfout_d01_2023-01-01_12:00:00
# URBPARM_UZE.TBL                    wrfout_d01_2023-01-01_13:00:00
# VEGPARM.TBL                        wrfout_d01_2023-01-01_14:00:00
# Vtable@                            wrfout_d01_2023-01-01_15:00:00
# aerosol.formatted                  wrfout_d01_2023-01-01_16:00:00
# aerosol_lat.formatted              wrfout_d01_2023-01-01_17:00:00
# aerosol_lon.formatted              wrfout_d01_2023-01-01_18:00:00
# aerosol_plev.formatted             wrfout_d02_2023-01-01_00:00:00
# bulkdens.asc_s_0_03_0_9            wrfout_d02_2023-01-01_01:00:00
# bulkradii.asc_s_0_03_0_9           wrfout_d02_2023-01-01_02:00:00
# capacity.asc                       wrfout_d02_2023-01-01_03:00:00
# co2_trans*                         wrfout_d02_2023-01-01_04:00:00
# coeff_p.asc                        wrfout_d02_2023-01-01_05:00:00
# coeff_q.asc                        wrfout_d02_2023-01-01_06:00:00
# constants.asc                      wrfout_d02_2023-01-01_07:00:00
# create_p3_lookupTable_1.f90-v5.4   wrfout_d02_2023-01-01_08:00:00
# create_p3_lookupTable_2.f90-v5.3   wrfout_d02_2023-01-01_09:00:00
# eclipse_besselian_elements.dat     wrfout_d02_2023-01-01_10:00:00
# freezeH2O.dat                      wrfout_d02_2023-01-01_11:00:00
# geo_em.d01.nc                      wrfout_d02_2023-01-01_12:00:00
# geo_em.d02.nc                      wrfout_d02_2023-01-01_13:00:00
# geogrid/                           wrfout_d02_2023-01-01_14:00:00
# geogrid.exe*                       wrfout_d02_2023-01-01_15:00:00
# geogrid.log                        wrfout_d02_2023-01-01_16:00:00
# grib2map.tbl                       wrfout_d02_2023-01-01_17:00:00
# gribmap.txt                        wrfout_d02_2023-01-01_18:00:00

# %% [markdown]
# ## modify name list

# %%
import re
def modify_namelist(namelist_path_in, namelist_path_out, aa):
    with open(namelist_path_in, 'r') as file:
        lines = file.readlines()


    for i, line in enumerate(lines):
        for k, v in aa.items():
            parameter_pattern = re.compile(rf'^\s*{k}\s*=\s*')
            if parameter_pattern.match(line):
                lines[i] = f' {k} = {v},\n'

    with open(namelist_path_out, 'w') as file:
        file.writelines(lines)

# %%
namelist_path_in = namelist_wps_path
namelist_path_out = run_dir+'/namelist.wps'
aa = {'geog_data_path': '"'+geogdir+'"' }

modify_namelist(namelist_path_in, namelist_path_out, aa)

# %%
cat control/namelist.wps
# Out:
# &share
#  wrf_core = 'ARW',
#  max_dom = 2,
#  start_date = '2023-01-01_00:00:00','2023-01-01_00:00:00',
#  end_date   = '2023-01-01_18:00:00','2023-01-01_18:00:00',
#  interval_seconds = 10800
# /
#
# &geogrid
#  parent_id         =   1,   1,
#  parent_grid_ratio =   1,   5,
#  i_parent_start    =   1,  20,
#  j_parent_start    =   1,  20,
#  e_we              =  50, 51,
#  e_sn              =  50, 51,
#  geog_data_res = 'modis_landuse_20class_30s_with_lakes','modis_landuse_20class_30s_with_lakes',
#  dx = 10000,
#  dy = 10000,
#  map_proj = 'lambert',
#  ref_lat   =  35.67,
#  ref_lon   = 139.65,
#  truelat1  =  30.0,
#  truelat2  =  60.0,
#  stand_lon = 139.0,
#  geog_data_path = "/Volumes/work/WRF_program/WPS_GEOG",
# /
#
# &ungrib
#  out_format = 'WPS',
#  prefix = 'ERA5S',
# /
#
# &metgrid
#  fg_name = 'ERA5P', 'ERA5S'
# /

# %% [markdown]
# ### Run geogrid.exe

# %%
os.system('cd '+run_dir+'; ./geogrid.exe  > NUL 2>&1; cd -')
# Out:
# /Users/doan/Documents/GitHub/Pseudo-Global-Warming-Downscaling/03_WRF_run
# 0

# %%
### Run ungrib

# %%
os.system('cd '+run_dir+';ln -sf ungrib/Variable_Tables/Vtable.ECMWF Vtable')
# Out:
# 0

# %%
namelist_wps = run_dir+'/namelist.wps'
prefixs = ['ERA5A', 'ERA5S']

for i in range(2):

    prefix = prefixs[i]
    reanal_files = renaldir + 'era5_ungrib_'+['pressure', 'surface'][i]+'_levels_20230101.grib'
    os.system('cd '+run_dir+';./link_grib.csh '+reanal_files)
    modify_namelist(namelist_wps, namelist_wps, { 'prefix'  :'"'+prefix+'"'  } )
    os.system('cd '+run_dir+'; ./ungrib.exe  > NUL 2>&1; cd -')
    #os.system('cd '+run_dir+'; ./ungrib.exe ')
# Out:
# /Users/doan/Documents/GitHub/Pseudo-Global-Warming-Downscaling/03_WRF_run
# /Users/doan/Documents/GitHub/Pseudo-Global-Warming-Downscaling/03_WRF_run

# %% [markdown]
# ### Run metgrid

# %%
fg_name = '"'+'","'.join(prefixs)+'"'

modify_namelist(namelist_wps, namelist_wps, { 'fg_name'  : fg_name} )

# %%
os.system('cd '+run_dir+'; ./metgrid.exe  > NUL 2>&1; cd -')
# Out:
# /Users/doan/Documents/GitHub/Pseudo-Global-Warming-Downscaling/03_WRF_run
# 0

# %% [markdown]
# ## Copy WRF run files

# %%
os.system('cp '+wrfdir+'/run/* '+ run_dir+'/')
# Out:
# 0

# %% [markdown]
# ### Modify namelist.input

# %%
wps = open(rundir+'/namelist.wps').readlines()
win = open(rundir+'/namelist.input').readlines()

vdinput = OrderedDict([(l.split('=')[0].strip(),l.split('=')[1].strip()) for l in win if len(l.split('=')) > 1])
vdwps   = OrderedDict([(l.split('=')[0].strip(),l.split('=')[1].strip()) for l in wps if len(l.split('=')) > 1])

max_dom           = int(vdwps['max_dom'][0])
dx                = int(vdwps['dx'].split(',')[0])
dy                = int(vdwps['dy'].split(',')[0])
parent_grid_ratio = list(map(int, vdwps['parent_grid_ratio'].split(',')))

#=== time_control
st, en = [ pd.to_datetime( vdwps[a].split(',')[0].replace("'","")  , format='%Y-%m-%d_%H:%M:%S') for a in ['start_date', 'end_date']]

vd = {}

vd['run_days']    = str((en - st).days)
vd['run_hours']   = str((en - st).seconds//3600)
vd['start_year']  = (str(st.year)+', ')*max_dom
vd['start_month'] = (str(st.month)+', ')*max_dom
vd['start_day']   = (str(st.day)+', ')*max_dom
vd['start_hour']  = (str(st.hour)+', ')*max_dom
vd['end_year']    = (str(en.year)+', ')*max_dom
vd['end_month']   = (str(en.month)+', ')*max_dom
vd['end_day']     = (str(en.day)+', ')*max_dom
vd['end_hour']    = (str(en.hour)+', ')*max_dom

for k in ['max_dom', 'e_we', 'e_sn', 
              'start_date', 'end_date', 
              'dx', 'dy',
              'parent_grid_ratio', 'i_parent_start', 'j_parent_start', 
              'fg_name']: 
    vd[k] = vdwps[k]



#===domains
dxs, dys =  np.array([dx]), np.array([dy])
for idom in range(1,max_dom):
    dxs = np.append(dxs, dxs[idom-1]/parent_grid_ratio[idom])
    dys = np.append(dys, dys[idom-1]/parent_grid_ratio[idom])

parent_id             = np.arange(max_dom)
parent_id[0]          = 1
vd['parent_id']      = ','.join(parent_id.astype('str'))
vd['grid_id'] = ','.join(np.arange(1,max_dom+1).astype('str'))
vd['dx'] = ', '.join(dxs.astype('str'))
vd['dy'] = ', '.join(dys.astype('str'))

e_vert = vdinput['e_vert'].split(',')[0]
vd['e_vert'] = ', '.join([e_vert]*max_dom)


parent_time_step_ratio = parent_grid_ratio
vd['parent_time_step_ratio'] = ', '.join(map(str,parent_time_step_ratio))
vd['time_step'] = str(dxs[0]*6/1000) 


for k, v in zip(['history_interval', 'frames_per_outfile'], ['60', '24']):
    vd[k] = (v+',')*max_dom

vd1 = get_met_em_info(wrfdir)
for k in list(vd1.keys()): vd[k] = vd1[k]

# Write all newly defined namelist2
for il, l in enumerate(win):
    k = l.split('=')[0].strip()
    if k in vd.keys(): 
        win[il] = k+'='+vd[k]+'\n'

open(wrfdir+'/namelist.input','w').write(''.join(win))

# %%
import re
with open(namelist_input_path, 'r') as file: a1 = file.readlines()
with open(run_dir+'/namelist.input', 'w') as file: file.writelines(a1)

# %%
cat control/namelist.input
# Out:
#  &time_control
#  run_days                            = 0,
#  run_hours                           = 36,
#  run_minutes                         = 0,
#  run_seconds                         = 0,
#  start_year                          = 2019, 2019,
#  start_month                         = 09,   09,
#  start_day                           = 04,   04,
#  start_hour                          = 12,   12,
#  end_year                            = 2019, 2019,
#  end_month                           = 09,   09,
#  end_day                             = 06,   06,
#  end_hour                            = 00,   00,
#  interval_seconds                    = 10800
#  input_from_file                     = .true.,.true.,
#  history_interval                    = 60,  60,
#  frames_per_outfile                  = 1, 1,
#  restart                             = .false.,
#  restart_interval                    = 7200,
#  io_form_history                     = 2
#  io_form_restart                     = 2
#  io_form_input                       = 2
#  io_form_boundary                    = 2
#  /
#
#  &domains
#  time_step                           = 90,
#  time_step_fract_num                 = 0,
#  time_step_fract_den                 = 1,
#  max_dom                             = 2,
#  e_we                                = 150,    220,
#  e_sn                                = 130,    214,
#  e_vert                              = 45,     45,
#  dzstretch_s                         = 1.1
#  p_top_requested                     = 5000,
#  num_metgrid_levels                  = 34,
#  num_metgrid_soil_levels             = 4,
#  dx                                  = 15000,
#  dy                                  = 15000,
#  grid_id                             = 1,     2,
#  parent_id                           = 0,     1,
#  i_parent_start                      = 1,     53,
#  j_parent_start                      = 1,     25,
#  parent_grid_ratio                   = 1,     3,
#  parent_time_step_ratio              = 1,     3,
#  feedback                            = 1,
#  smooth_option                       = 0
#  /
#
#  &physics
#  physics_suite                       = 'CONUS'
#  mp_physics                          = -1,    -1,
#  cu_physics                          = -1,    -1,
#  ra_lw_physics                       = -1,    -1,
#  ra_sw_physics                       = -1,    -1,
#  bl_pbl_physics                      = -1,    -1,
#  sf_sfclay_physics                   = -1,    -1,
#  sf_surface_physics                  = -1,    -1,
#  radt                                = 15,    15,
#  bldt                                = 0,     0,
#  cudt                                = 0,     0,
#  icloud                              = 1,
#  num_land_cat                        = 21,
#  sf_urban_physics                    = 0,     0,
#  fractional_seaice                   = 1,
#  /
#
#  &fdda
#  /
#
#  &dynamics
#  hybrid_opt                          = 2,
#  w_damping                           = 0,
#  diff_opt                            = 2,      2,
#  km_opt                              = 4,      4,
#  diff_6th_opt                        = 0,      0,
#  diff_6th_factor                     = 0.12,   0.12,
#  base_temp                           = 290.
#  damp_opt                            = 3,
#  zdamp                               = 5000.,  5000.,
#  dampcoef                            = 0.2,    0.2,
#  khdif                               = 0,      0,
#  kvdif                               = 0,      0,
#  non_hydrostatic                     = .true., .true.,
#  moist_adv_opt                       = 1,      1,
#  scalar_adv_opt                      = 1,      1,
#  gwd_opt                             = 1,      0,
#  /
#
#  &bdy_control
#  spec_bdy_width                      = 5,
#  specified                           = .true.
#  /
#
#  &grib2
#  /
#
#  &namelist_quilt
#  nio_tasks_per_group = 0,
#  nio_groups = 1,
#  /

# %%
os.system('cd '+run_dir+'; ./real.exe  ; cd -')
# Out:
#  Ntasks in X            1 , ntasks in Y            1
# *************************************
# Configuring physics suite 'conus'
#
#          mp_physics:      8      8
#          cu_physics:      6      6
#       ra_lw_physics:      4      4
#       ra_sw_physics:      4      4
#      bl_pbl_physics:      2      2
#   sf_sfclay_physics:      2      2
#  sf_surface_physics:      2      2
# *************************************
#   Domain # 1: dx = 10000.000 m
#   Domain # 2: dx =  2000.000 m
# REAL_EM V4.6.0 PREPROCESSOR
# git commit 0a11865f97680fdd6865b278ea29d910e5db3ed7 1 file changed, 3 insertions(+), 3 deletions(-)
#  *************************************
#  Parent domain
#  ids,ide,jds,jde            1          50           1          50
#  ims,ime,jms,jme           -4          55          -4          55
#  ips,ipe,jps,jpe            1          50           1          50
#  *************************************
# DYNAMICS OPTION: Eulerian Mass Coordinate
#    alloc_space_field: domain            1 ,             141273076  bytes allocated
# Time period #   1 to process = 2023-01-01_00:00:00.
# Time period #   2 to process = 2023-01-01_03:00:00.
# Time period #   3 to process = 2023-01-01_06:00:00.
# Time period #   4 to process = 2023-01-01_09:00:00.
# Time period #   5 to process = 2023-01-01_12:00:00.
# Time period #   6 to process = 2023-01-01_15:00:00.
# Time period #   7 to process = 2023-01-01_18:00:00.
# Total analysis times to input =    7.
#
#  -----------------------------------------------------------------------------
#
#  Domain  1: Current date being processed: 2023-01-01_00:00:00.0000, which is loop #   1 out of    7
#  configflags%julyr, %julday, %gmt:        2023           1   0.00000000
# d01 2023-01-01_00:00:00  Yes, this special data is acceptable to use: OUTPUT FROM METGRID V4.6.0
# d01 2023-01-01_00:00:00  Input data is acceptable to use: met_em.d01.2023-01-01_00:00:00.nc
#  metgrid input_wrf.F first_date_input = 2023-01-01_00:00:00
#  metgrid input_wrf.F first_date_nml = 2023-01-01_00:00:00
# d01 2023-01-01_00:00:00 Timing for input          0 s.
# d01 2023-01-01_00:00:00          flag_soil_layers read from met_em file is  1
# Max map factor in domain 1 =  0.99. Scale the dt in the model accordingly.
# Using sfcprs  to compute psfc
#  using new automatic levels program
#            1   50.0000000       50.0000000      0.993814707
#            2   55.0000000       105.000000      0.987052977       1.10000002
#            3   60.5000000       165.500000      0.979665458       1.10000002
#            4   66.5500031       232.050003      0.971599758       1.10000002
#            5   73.2050018       305.255005      0.962800324       1.10000002
#            6   80.5255051       385.780518      0.953208208       1.10000002
#            7   88.5780563       474.358582      0.942761540       1.10000002
#            8   97.4358673       571.794434      0.931395411       1.10000002
#            9   107.179459       678.973877      0.919042587       1.10000002
#           10   117.897408       796.871277      0.905633450       1.10000002
#           11   129.687149       926.558411      0.891097128       1.10000002
#           12   142.655869       1069.21423      0.875361621       1.10000002
#           13   156.921463       1226.13574      0.858355403       1.10000002
#           14   172.613617       1398.74939      0.840008378       1.10000002
#           15   189.874985       1588.62439      0.820253134       1.10000002
#           16   208.862488       1797.48682      0.799026966       1.10000002
#           17   229.748749       2027.23560      0.776273906       1.10000002
#           18   252.723633       2279.95923      0.751946986       1.10000002
#           19   277.996002       2557.95532      0.726011097       1.10000002
#           20   305.795624       2863.75098      0.698446214       1.10000002
#           21   336.375183       3200.12622      0.669250667       1.10000002
#           22   370.012695       3570.13892      0.638444543       1.10000002
#           23   407.013977       3977.15283      0.606074095       1.10000002
#           24   447.715393       4424.86816      0.572215140       1.10000002
#           25   492.486938       4917.35498      0.536976993       1.10000002
#           26   541.735657       5459.09082      0.500505865       1.10000002
#           27   595.909241       6055.00000      0.462987870       1.10000002
#           28   655.500183       6710.50000      0.424650490       1.10000002
#           29   721.050232       7431.55029      0.385763407       1.10000002
#           30   793.155273       8224.70508      0.346636951       1.10000002
#           31   872.470825       9097.17578      0.307618916       1.10000002
#           32   959.717957       10056.8936      0.269088268       1.10000002
#           33   1055.68982       11112.5830      0.231447041       1.10000002
#           34   1161.25879       12273.8418      0.195107996       1.10000002
#           35   1277.38464       13551.2266      0.160480365       1.10000002
#    25416.3906       13551.2266              44          35
#           36   1318.35156       14869.5781      0.129809752
#           37   1318.35156       16187.9297      0.103553154
#           38   1318.35156       17506.2812       8.10753629E-02
#           39   1318.35156       18824.6328       6.18325360E-02
#           40   1318.35156       20142.9844       4.53590974E-02
#           41   1318.35156       21461.3359       3.12564746E-02
#           42   1318.35156       22779.6875       1.91834755E-02
#           43   1318.35156       24098.0391       8.84801615E-03
#           44   1318.35156       25416.3906       1.02796056E-08
#     1.0000    0.9938    0.9871    0.9797    0.9716    0.9628    0.9532    0.9428    0.9314    0.9190
#     0.9056    0.8911    0.8754    0.8584    0.8400    0.8203    0.7990    0.7763    0.7519    0.7260
#     0.6984    0.6693    0.6384    0.6061    0.5722    0.5370    0.5005    0.4630    0.4247    0.3858
#     0.3466    0.3076    0.2691    0.2314    0.1951    0.1605    0.1298    0.1036    0.0811    0.0618
#     0.0454    0.0313    0.0192    0.0088    0.0000
# Full level index =    1     Height =     0.0 m
# Full level index =    2     Height =    50.0 m      Thickness =   50.0 m
# Full level index =    3     Height =   104.9 m      Thickness =   54.9 m
# Full level index =    4     Height =   165.2 m      Thickness =   60.3 m
# Full level index =    5     Height =   231.5 m      Thickness =   66.3 m
# Full level index =    6     Height =   304.3 m      Thickness =   72.8 m
# Full level index =    7     Height =   384.3 m      Thickness =   80.0 m
# Full level index =    8     Height =   472.1 m      Thickness =   87.8 m
# Full level index =    9     Height =   568.5 m      Thickness =   96.4 m
# Full level index =   10     Height =   674.3 m      Thickness =  105.8 m
# Full level index =   11     Height =   790.4 m      Thickness =  116.1 m
# Full level index =   12     Height =   917.8 m      Thickness =  127.4 m
# Full level index =   13     Height =  1057.6 m      Thickness =  139.8 m
# Full level index =   14     Height =  1210.8 m      Thickness =  153.3 m
# Full level index =   15     Height =  1378.9 m      Thickness =  168.0 m
# Full level index =   16     Height =  1563.0 m      Thickness =  184.1 m
# Full level index =   17     Height =  1764.6 m      Thickness =  201.7 m
# Full level index =   18     Height =  1985.4 m      Thickness =  220.8 m
# Full level index =   19     Height =  2227.1 m      Thickness =  241.6 m
# Full level index =   20     Height =  2491.4 m      Thickness =  264.3 m
# Full level index =   21     Height =  2780.3 m      Thickness =  288.9 m
# Full level index =   22     Height =  3095.9 m      Thickness =  315.6 m
# Full level index =   23     Height =  3440.5 m      Thickness =  344.5 m
# Full level index =   24     Height =  3816.2 m      Thickness =  375.7 m
# Full level index =   25     Height =  4225.6 m      Thickness =  409.4 m
# Full level index =   26     Height =  4671.3 m      Thickness =  445.6 m
# Full level index =   27     Height =  5155.8 m      Thickness =  484.5 m
# Full level index =   28     Height =  5681.8 m      Thickness =  526.0 m
# Full level index =   29     Height =  6252.1 m      Thickness =  570.3 m
# Full level index =   30     Height =  6869.3 m      Thickness =  617.2 m
# Full level index =   31     Height =  7535.9 m      Thickness =  666.6 m
# Full level index =   32     Height =  8254.4 m      Thickness =  718.5 m
# Full level index =   33     Height =  9026.8 m      Thickness =  772.4 m
# Full level index =   34     Height =  9854.7 m      Thickness =  827.9 m
# Full level index =   35     Height = 10739.1 m      Thickness =  884.4 m
# Full level index =   36     Height = 11680.1 m      Thickness =  941.0 m
# Full level index =   37     Height = 12616.6 m      Thickness =  936.4 m
# Full level index =   38     Height = 13523.9 m      Thickness =  907.4 m
# Full level index =   39     Height = 14431.3 m      Thickness =  907.4 m
# Full level index =   40     Height = 15338.7 m      Thickness =  907.4 m
# Full level index =   41     Height = 16246.1 m      Thickness =  907.4 m
# Full level index =   42     Height = 17153.5 m      Thickness =  907.4 m
# Full level index =   43     Height = 18060.9 m      Thickness =  907.4 m
# Full level index =   44     Height = 18968.2 m      Thickness =  907.4 m
# Full level index =   45     Height = 19875.6 m      Thickness =  907.4 m
# p_top =   5000. Pa, dzbot =   50.0 m, dzstretch_s/u =   1.10  1.10
# d01 2023-01-01_00:00:00 No average surface temperature for use with inland lakes
#  Assume Noah LSM input
# d01 2023-01-01_00:00:00 forcing artificial silty clay loam at   40 points, out of   2401
# d01 2023-01-01_00:00:00 Timing for processing          0 s.
# d01 2023-01-01_00:00:00 Timing for output          0 s.
# d01 2023-01-01_00:00:00 Timing for loop #    1 =          0 s.
#
#  -----------------------------------------------------------------------------
#
#  Domain  1: Current date being processed: 2023-01-01_03:00:00.0000, which is loop #   2 out of    7
#  configflags%julyr, %julday, %gmt:        2023           1   3.00000000
# d01 2023-01-01_03:00:00  Yes, this special data is acceptable to use: OUTPUT FROM METGRID V4.6.0
# d01 2023-01-01_03:00:00  Input data is acceptable to use: met_em.d01.2023-01-01_03:00:00.nc
#  metgrid input_wrf.F first_date_input = 2023-01-01_03:00:00
#  metgrid input_wrf.F first_date_nml = 2023-01-01_00:00:00
# d01 2023-01-01_03:00:00 Timing for input          0 s.
# d01 2023-01-01_03:00:00          flag_soil_layers read from met_em file is  1
# Using sfcprs  to compute psfc
# d01 2023-01-01_03:00:00 No average surface temperature for use with inland lakes
#  Assume Noah LSM input
# d01 2023-01-01_03:00:00 forcing artificial silty clay loam at   18 points, out of   2401
# d01 2023-01-01_03:00:00 Timing for processing          0 s.
#  LBC valid between these times 2023-01-01_00:00:00 and 2023-01-01_03:00:00
# d01 2023-01-01_03:00:00 Timing for output          0 s.
# d01 2023-01-01_03:00:00 Timing for loop #    2 =          0 s.
#
#  -----------------------------------------------------------------------------
#
#  Domain  1: Current date being processed: 2023-01-01_06:00:00.0000, which is loop #   3 out of    7
#  configflags%julyr, %julday, %gmt:        2023           1   6.00000000
# d01 2023-01-01_06:00:00  Yes, this special data is acceptable to use: OUTPUT FROM METGRID V4.6.0
# d01 2023-01-01_06:00:00  Input data is acceptable to use: met_em.d01.2023-01-01_06:00:00.nc
#  metgrid input_wrf.F first_date_input = 2023-01-01_06:00:00
#  metgrid input_wrf.F first_date_nml = 2023-01-01_00:00:00
# d01 2023-01-01_06:00:00 Timing for input          0 s.
# d01 2023-01-01_06:00:00          flag_soil_layers read from met_em file is  1
# Using sfcprs  to compute psfc
# d01 2023-01-01_06:00:00 No average surface temperature for use with inland lakes
#  Assume Noah LSM input
# d01 2023-01-01_06:00:00 forcing artificial silty clay loam at   18 points, out of   2401
# d01 2023-01-01_06:00:00 Timing for processing          0 s.
#  LBC valid between these times 2023-01-01_03:00:00 and 2023-01-01_06:00:00
# d01 2023-01-01_06:00:00 Timing for output          0 s.
# d01 2023-01-01_06:00:00 Timing for loop #    3 =          0 s.
#
#  -----------------------------------------------------------------------------
#
#  Domain  1: Current date being processed: 2023-01-01_09:00:00.0000, which is loop #   4 out of    7
#  configflags%julyr, %julday, %gmt:        2023           1   9.00000000
# d01 2023-01-01_09:00:00  Yes, this special data is acceptable to use: OUTPUT FROM METGRID V4.6.0
# d01 2023-01-01_09:00:00  Input data is acceptable to use: met_em.d01.2023-01-01_09:00:00.nc
#  metgrid input_wrf.F first_date_input = 2023-01-01_09:00:00
#  metgrid input_wrf.F first_date_nml = 2023-01-01_00:00:00
# d01 2023-01-01_09:00:00 Timing for input          0 s.
# d01 2023-01-01_09:00:00          flag_soil_layers read from met_em file is  1
# Using sfcprs  to compute psfc
# d01 2023-01-01_09:00:00 No average surface temperature for use with inland lakes
#  Assume Noah LSM input
# d01 2023-01-01_09:00:00 forcing artificial silty clay loam at   18 points, out of   2401
# d01 2023-01-01_09:00:00 Timing for processing          0 s.
#  LBC valid between these times 2023-01-01_06:00:00 and 2023-01-01_09:00:00
# d01 2023-01-01_09:00:00 Timing for output          0 s.
# d01 2023-01-01_09:00:00 Timing for loop #    4 =          0 s.
#
#  -----------------------------------------------------------------------------
#
#  Domain  1: Current date being processed: 2023-01-01_12:00:00.0000, which is loop #   5 out of    7
#  configflags%julyr, %julday, %gmt:        2023           1   12.0000000
# d01 2023-01-01_12:00:00  Yes, this special data is acceptable to use: OUTPUT FROM METGRID V4.6.0
# d01 2023-01-01_12:00:00  Input data is acceptable to use: met_em.d01.2023-01-01_12:00:00.nc
#  metgrid input_wrf.F first_date_input = 2023-01-01_12:00:00
#  metgrid input_wrf.F first_date_nml = 2023-01-01_00:00:00
# d01 2023-01-01_12:00:00 Timing for input          0 s.
# d01 2023-01-01_12:00:00          flag_soil_layers read from met_em file is  1
# Using sfcprs  to compute psfc
# d01 2023-01-01_12:00:00 No average surface temperature for use with inland lakes
#  Assume Noah LSM input
# d01 2023-01-01_12:00:00 forcing artificial silty clay loam at   18 points, out of   2401
# d01 2023-01-01_12:00:00 Timing for processing          0 s.
#  LBC valid between these times 2023-01-01_09:00:00 and 2023-01-01_12:00:00
# d01 2023-01-01_12:00:00 Timing for output          0 s.
# d01 2023-01-01_12:00:00 Timing for loop #    5 =          0 s.
#
#  -----------------------------------------------------------------------------
#
#  Domain  1: Current date being processed: 2023-01-01_15:00:00.0000, which is loop #   6 out of    7
#  configflags%julyr, %julday, %gmt:        2023           1   15.0000000
# d01 2023-01-01_15:00:00  Yes, this special data is acceptable to use: OUTPUT FROM METGRID V4.6.0
# d01 2023-01-01_15:00:00  Input data is acceptable to use: met_em.d01.2023-01-01_15:00:00.nc
#  metgrid input_wrf.F first_date_input = 2023-01-01_15:00:00
#  metgrid input_wrf.F first_date_nml = 2023-01-01_00:00:00
# d01 2023-01-01_15:00:00 Timing for input          0 s.
# d01 2023-01-01_15:00:00          flag_soil_layers read from met_em file is  1
# Using sfcprs  to compute psfc
# d01 2023-01-01_15:00:00 No average surface temperature for use with inland lakes
#  Assume Noah LSM input
# d01 2023-01-01_15:00:00 forcing artificial silty clay loam at   18 points, out of   2401
# d01 2023-01-01_15:00:00 Timing for processing          0 s.
#  LBC valid between these times 2023-01-01_12:00:00 and 2023-01-01_15:00:00
# d01 2023-01-01_15:00:00 Timing for output          0 s.
# d01 2023-01-01_15:00:00 Timing for loop #    6 =          0 s.
#
#  -----------------------------------------------------------------------------
#
#  Domain  1: Current date being processed: 2023-01-01_18:00:00.0000, which is loop #   7 out of    7
#  configflags%julyr, %julday, %gmt:        2023           1   18.0000000
# d01 2023-01-01_18:00:00  Yes, this special data is acceptable to use: OUTPUT FROM METGRID V4.6.0
# d01 2023-01-01_18:00:00  Input data is acceptable to use: met_em.d01.2023-01-01_18:00:00.nc
#  metgrid input_wrf.F first_date_input = 2023-01-01_18:00:00
#  metgrid input_wrf.F first_date_nml = 2023-01-01_00:00:00
# d01 2023-01-01_18:00:00 Timing for input          0 s.
# d01 2023-01-01_18:00:00          flag_soil_layers read from met_em file is  1
# Using sfcprs  to compute psfc
# d01 2023-01-01_18:00:00 No average surface temperature for use with inland lakes
#  Assume Noah LSM input
# d01 2023-01-01_18:00:00 forcing artificial silty clay loam at   18 points, out of   2401
# d01 2023-01-01_18:00:00 Timing for processing          0 s.
#  LBC valid between these times 2023-01-01_15:00:00 and 2023-01-01_18:00:00
# d01 2023-01-01_18:00:00 Timing for output          0 s.
# d01 2023-01-01_18:00:00 Timing for loop #    7 =          0 s.
#  *************************************
#  Nesting domain
#  ids,ide,jds,jde            1          51           1          51
#  ims,ime,jms,jme           -4          60          -4          60
#  ips,ipe,jps,jpe            1          51           1          51
#  INTERMEDIATE domain
#  ids,ide,jds,jde           18          33          18          33
#  ims,ime,jms,jme           13          38          13          38
#  ips,ipe,jps,jpe           16          35          16          35
#  *************************************
# d01 2023-01-01_18:00:00  alloc_space_field: domain            2 ,               8593312  bytes allocated
# d01 2023-01-01_18:00:00  alloc_space_field: domain            2 ,             164239688  bytes allocated
# Time period #   1 to process = 2023-01-01_00:00:00.
# Time period #   2 to process = 2023-01-01_03:00:00.
# Time period #   3 to process = 2023-01-01_06:00:00.
# Time period #   4 to process = 2023-01-01_09:00:00.
# Time period #   5 to process = 2023-01-01_12:00:00.
# Time period #   6 to process = 2023-01-01_15:00:00.
# Time period #   7 to process = 2023-01-01_18:00:00.
# Total analysis times to input =    7.
#
#  -----------------------------------------------------------------------------
#
#  Domain  2: Current date being processed: 2023-01-01_00:00:00.0000, which is loop #   1 out of    7
#  configflags%julyr, %julday, %gmt:        2023           1   0.00000000
# d02 2023-01-01_00:00:00  Yes, this special data is acceptable to use: OUTPUT FROM METGRID V4.6.0
# d02 2023-01-01_00:00:00  Input data is acceptable to use: met_em.d02.2023-01-01_00:00:00.nc
#  metgrid input_wrf.F first_date_input = 2023-01-01_00:00:00
#  metgrid input_wrf.F first_date_nml = 2023-01-01_00:00:00
# d02 2023-01-01_00:00:00 Timing for input          0 s.
# d02 2023-01-01_00:00:00          flag_soil_layers read from met_em file is  1
# Using sfcprs  to compute psfc
#  using new automatic levels program
#            1   50.0000000       50.0000000      0.993814707
#            2   55.0000000       105.000000      0.987052977       1.10000002
#            3   60.5000000       165.500000      0.979665458       1.10000002
#            4   66.5500031       232.050003      0.971599758       1.10000002
#            5   73.2050018       305.255005      0.962800324       1.10000002
#            6   80.5255051       385.780518      0.953208208       1.10000002
#            7   88.5780563       474.358582      0.942761540       1.10000002
#            8   97.4358673       571.794434      0.931395411       1.10000002
#            9   107.179459       678.973877      0.919042587       1.10000002
#           10   117.897408       796.871277      0.905633450       1.10000002
#           11   129.687149       926.558411      0.891097128       1.10000002
#           12   142.655869       1069.21423      0.875361621       1.10000002
#           13   156.921463       1226.13574      0.858355403       1.10000002
#           14   172.613617       1398.74939      0.840008378       1.10000002
#           15   189.874985       1588.62439      0.820253134       1.10000002
#           16   208.862488       1797.48682      0.799026966       1.10000002
#           17   229.748749       2027.23560      0.776273906       1.10000002
#           18   252.723633       2279.95923      0.751946986       1.10000002
#           19   277.996002       2557.95532      0.726011097       1.10000002
#           20   305.795624       2863.75098      0.698446214       1.10000002
#           21   336.375183       3200.12622      0.669250667       1.10000002
#           22   370.012695       3570.13892      0.638444543       1.10000002
#           23   407.013977       3977.15283      0.606074095       1.10000002
#           24   447.715393       4424.86816      0.572215140       1.10000002
#           25   492.486938       4917.35498      0.536976993       1.10000002
#           26   541.735657       5459.09082      0.500505865       1.10000002
#           27   595.909241       6055.00000      0.462987870       1.10000002
#           28   655.500183       6710.50000      0.424650490       1.10000002
#           29   721.050232       7431.55029      0.385763407       1.10000002
#           30   793.155273       8224.70508      0.346636951       1.10000002
#           31   872.470825       9097.17578      0.307618916       1.10000002
#           32   959.717957       10056.8936      0.269088268       1.10000002
#           33   1055.68982       11112.5830      0.231447041       1.10000002
#           34   1161.25879       12273.8418      0.195107996       1.10000002
#           35   1277.38464       13551.2266      0.160480365       1.10000002
#    25416.3906       13551.2266              44          35
#           36   1318.35156       14869.5781      0.129809752
#           37   1318.35156       16187.9297      0.103553154
#           38   1318.35156       17506.2812       8.10753629E-02
#           39   1318.35156       18824.6328       6.18325360E-02
#           40   1318.35156       20142.9844       4.53590974E-02
#           41   1318.35156       21461.3359       3.12564746E-02
#           42   1318.35156       22779.6875       1.91834755E-02
#           43   1318.35156       24098.0391       8.84801615E-03
#           44   1318.35156       25416.3906       1.02796056E-08
#     1.0000    0.9938    0.9871    0.9797    0.9716    0.9628    0.9532    0.9428    0.9314    0.9190
#     0.9056    0.8911    0.8754    0.8584    0.8400    0.8203    0.7990    0.7763    0.7519    0.7260
#     0.6984    0.6693    0.6384    0.6061    0.5722    0.5370    0.5005    0.4630    0.4247    0.3858
#     0.3466    0.3076    0.2691    0.2314    0.1951    0.1605    0.1298    0.1036    0.0811    0.0618
#     0.0454    0.0313    0.0192    0.0088    0.0000
# Full level index =    1     Height =     0.0 m
# Full level index =    2     Height =    50.0 m      Thickness =   50.0 m
# Full level index =    3     Height =   104.9 m      Thickness =   54.9 m
# Full level index =    4     Height =   165.2 m      Thickness =   60.3 m
# Full level index =    5     Height =   231.5 m      Thickness =   66.3 m
# Full level index =    6     Height =   304.3 m      Thickness =   72.8 m
# Full level index =    7     Height =   384.3 m      Thickness =   80.0 m
# Full level index =    8     Height =   472.1 m      Thickness =   87.8 m
# Full level index =    9     Height =   568.5 m      Thickness =   96.4 m
# Full level index =   10     Height =   674.3 m      Thickness =  105.8 m
# Full level index =   11     Height =   790.4 m      Thickness =  116.1 m
# Full level index =   12     Height =   917.8 m      Thickness =  127.4 m
# Full level index =   13     Height =  1057.6 m      Thickness =  139.8 m
# Full level index =   14     Height =  1210.8 m      Thickness =  153.3 m
# Full level index =   15     Height =  1378.9 m      Thickness =  168.0 m
# Full level index =   16     Height =  1563.0 m      Thickness =  184.1 m
# Full level index =   17     Height =  1764.6 m      Thickness =  201.7 m
# Full level index =   18     Height =  1985.4 m      Thickness =  220.8 m
# Full level index =   19     Height =  2227.1 m      Thickness =  241.6 m
# Full level index =   20     Height =  2491.4 m      Thickness =  264.3 m
# Full level index =   21     Height =  2780.3 m      Thickness =  288.9 m
# Full level index =   22     Height =  3095.9 m      Thickness =  315.6 m
# Full level index =   23     Height =  3440.5 m      Thickness =  344.5 m
# Full level index =   24     Height =  3816.2 m      Thickness =  375.7 m
# Full level index =   25     Height =  4225.6 m      Thickness =  409.4 m
# Full level index =   26     Height =  4671.3 m      Thickness =  445.6 m
# Full level index =   27     Height =  5155.8 m      Thickness =  484.5 m
# Full level index =   28     Height =  5681.8 m      Thickness =  526.0 m
# Full level index =   29     Height =  6252.1 m      Thickness =  570.3 m
# Full level index =   30     Height =  6869.3 m      Thickness =  617.2 m
# Full level index =   31     Height =  7535.9 m      Thickness =  666.6 m
# Full level index =   32     Height =  8254.4 m      Thickness =  718.5 m
# Full level index =   33     Height =  9026.8 m      Thickness =  772.4 m
# Full level index =   34     Height =  9854.7 m      Thickness =  827.9 m
# Full level index =   35     Height = 10739.1 m      Thickness =  884.4 m
# Full level index =   36     Height = 11680.1 m      Thickness =  941.0 m
# Full level index =   37     Height = 12616.6 m      Thickness =  936.4 m
# Full level index =   38     Height = 13523.9 m      Thickness =  907.4 m
# Full level index =   39     Height = 14431.3 m      Thickness =  907.4 m
# Full level index =   40     Height = 15338.7 m      Thickness =  907.4 m
# Full level index =   41     Height = 16246.1 m      Thickness =  907.4 m
# Full level index =   42     Height = 17153.5 m      Thickness =  907.4 m
# Full level index =   43     Height = 18060.9 m      Thickness =  907.4 m
# Full level index =   44     Height = 18968.2 m      Thickness =  907.4 m
# Full level index =   45     Height = 19875.6 m      Thickness =  907.4 m
# p_top =   5000. Pa, dzbot =   50.0 m, dzstretch_s/u =   1.10  1.10
# d02 2023-01-01_00:00:00 No average surface temperature for use with inland lakes
#  Assume Noah LSM input
# d02 2023-01-01_00:00:00 forcing artificial silty clay loam at  139 points, out of   2500
# d02 2023-01-01_00:00:00 Timing for processing          0 s.
# d02 2023-01-01_00:00:00 Timing for output          0 s.
# d02 2023-01-01_00:00:00 Timing for loop #    1 =          0 s.
# d01 2023-01-01_18:00:00 real_em: SUCCESS COMPLETE REAL_EM INIT
# /Users/doan/Documents/GitHub/Pseudo-Global-Warming-Downscaling/03_WRF_run
# 0

# %%
os.system('cd '+run_dir+'; ./wrf.exe  ; cd -')
# Out:
#  Ntasks in X            1 , ntasks in Y            1
# *************************************
# Configuring physics suite 'conus'
#
#          mp_physics:      8      8
#          cu_physics:      6      6
#       ra_lw_physics:      4      4
#       ra_sw_physics:      4      4
#      bl_pbl_physics:      2      2
#   sf_sfclay_physics:      2      2
#  sf_surface_physics:      2      2
# *************************************
#   Domain # 1: dx = 10000.000 m
#   Domain # 2: dx =  2000.000 m
# WRF V4.6.0 MODEL
# git commit 0a11865f97680fdd6865b278ea29d910e5db3ed7 1 file changed, 3 insertions(+), 3 deletions(-)
#  *************************************
#  Parent domain
#  ids,ide,jds,jde            1          50           1          50
#  ims,ime,jms,jme           -4          55          -4          55
#  ips,ipe,jps,jpe            1          50           1          50
#  *************************************
# DYNAMICS OPTION: Eulerian Mass Coordinate
#    alloc_space_field: domain            1 ,             123661876  bytes allocated
#   med_initialdata_input: calling input_input
#    Input data is acceptable to use: wrfinput_d01
#  CURRENT DATE          = 2023-01-01_00:00:00
#  SIMULATION START DATE = 2023-01-01_00:00:00
# Timing for processing wrfinput file (stream 0) for domain        1:    0.10772 elapsed seconds
# Max map factor in domain 1 =  0.99. Scale the dt in the model accordingly.
#  D01: Time step                              =    30.0000000      (s)
#  D01: Grid Distance                          =    10.0000000      (km)
#  D01: Grid Distance Ratio dt/dx              =    3.00000000      (s/km)
#  D01: Ratio Including Maximum Map Factor     =    2.96027613      (s/km)
#  D01: NML defined reasonable_time_step_ratio =    6.00000000
#  Climate GHG input from file from year         1765  to         2499
#  CO2   range =    277.91300000000001        579.26400000000001       ppm
#  N2O   range =    274.37200000000001        359.79800000000000       ppb
#  CH4   range =    738.98599999999999        997.31100000000004       ppb
#  CFC11 range =    0.0000000000000000        1.4000000000000000E-002  ppt
#  CFC12 range =    0.0000000000000000        2.8809999999999998       ppt
#  Normal ending of CAMtr_volume_mixing_ratio file
#  GHG annual values from CAM trace gas file
#  Year =         2023 , Julian day =            1
#  CO2   =    4.2180985372190533E-004  volume mixing ratio
#  N2O   =    3.3404662616691106E-007  volume mixing ratio
#  CH4   =    1.9375017123011811E-006  volume mixing ratio
#  CFC11 =    2.1122290601253179E-010  volume mixing ratio
#  CFC12 =    4.8310399534210311E-010  volume mixing ratio
# INPUT LandUse = "MODIFIED_IGBP_MODIS_NOAH"
#  LANDUSE TYPE = "MODIFIED_IGBP_MODIS_NOAH" FOUND          61  CATEGORIES           2  SEASONS WATER CATEGORY =           17  SNOW CATEGORY =           15
# INITIALIZE THREE Noah LSM RELATED TABLES
# Skipping over LUTYPE = USGS
#  LANDUSE TYPE = MODIFIED_IGBP_MODIS_NOAH FOUND          20  CATEGORIES
#  INPUT SOIL TEXTURE CLASSIFICATION = STAS
#  SOIL TEXTURE CLASSIFICATION = STAS FOUND          19  CATEGORIES
# ThompMP: read qr_acr_qg_V4.dat     instead of computing
# ThompMP: read qr_acr_qsV2.dat instead of computing
# ThompMP: read freezeH2O.dat instead of computing
#  *************************************
#  Nesting domain
#  ids,ide,jds,jde            1          51           1          51
#  ims,ime,jms,jme           -4          60          -4          60
#  ips,ipe,jps,jpe            1          51           1          51
#  INTERMEDIATE domain
#  ids,ide,jds,jde           18          33          18          33
#  ims,ime,jms,jme           13          38          13          38
#  ips,ipe,jps,jpe           16          35          16          35
#  *************************************
# d01 2023-01-01_00:00:00  alloc_space_field: domain            2 ,               8593312  bytes allocated
# d01 2023-01-01_00:00:00  alloc_space_field: domain            2 ,             143570988  bytes allocated
# d01 2023-01-01_00:00:00 *** Initializing nest domain # 2 from an input file. ***
# d01 2023-01-01_00:00:00 med_initialdata_input: calling input_input
# d01 2023-01-01_00:00:00  Input data is acceptable to use: wrfinput_d02
# Timing for processing wrfinput file (stream 0) for domain        2:    0.07763 elapsed seconds
#  Climate GHG input from file from year         1765  to         2499
#  CO2   range =    277.91300000000001        579.26400000000001       ppm
#  N2O   range =    274.37200000000001        359.79800000000000       ppb
#  CH4   range =    738.98599999999999        997.31100000000004       ppb
#  CFC11 range =    0.0000000000000000        1.4000000000000000E-002  ppt
#  CFC12 range =    0.0000000000000000        2.8809999999999998       ppt
#  Normal ending of CAMtr_volume_mixing_ratio file
#  GHG annual values from CAM trace gas file
#  Year =         2023 , Julian day =            1
#  CO2   =    4.2180985372190533E-004  volume mixing ratio
#  N2O   =    3.3404662616691106E-007  volume mixing ratio
#  CH4   =    1.9375017123011811E-006  volume mixing ratio
#  CFC11 =    2.1122290601253179E-010  volume mixing ratio
#  CFC12 =    4.8310399534210311E-010  volume mixing ratio
# INPUT LandUse = "MODIFIED_IGBP_MODIS_NOAH"
#  LANDUSE TYPE = "MODIFIED_IGBP_MODIS_NOAH" FOUND          61  CATEGORIES           2  SEASONS WATER CATEGORY =           17  SNOW CATEGORY =           15
# INITIALIZE THREE Noah LSM RELATED TABLES
# Skipping over LUTYPE = USGS
#  LANDUSE TYPE = MODIFIED_IGBP_MODIS_NOAH FOUND          20  CATEGORIES
#  INPUT SOIL TEXTURE CLASSIFICATION = STAS
#  SOIL TEXTURE CLASSIFICATION = STAS FOUND          19  CATEGORIES
#  Climate GHG input from file from year         1765  to         2499
#  CO2   range =    277.91300000000001        579.26400000000001       ppm
#  N2O   range =    274.37200000000001        359.79800000000000       ppb
#  CH4   range =    738.98599999999999        997.31100000000004       ppb
#  CFC11 range =    0.0000000000000000        1.4000000000000000E-002  ppt
#  CFC12 range =    0.0000000000000000        2.8809999999999998       ppt
#  Normal ending of CAMtr_volume_mixing_ratio file
#  GHG annual values from CAM trace gas file
#  Year =         2023 , Julian day =            1
#  CO2   =    4.2180985372190533E-004  volume mixing ratio
#  N2O   =    3.3404662616691106E-007  volume mixing ratio
#  CH4   =    1.9375017123011811E-006  volume mixing ratio
#  CFC11 =    2.1122290601253179E-010  volume mixing ratio
#  CFC12 =    4.8310399534210311E-010  volume mixing ratio
# INPUT LandUse = "MODIFIED_IGBP_MODIS_NOAH"
#  LANDUSE TYPE = "MODIFIED_IGBP_MODIS_NOAH" FOUND          61  CATEGORIES           2  SEASONS WATER CATEGORY =           17  SNOW CATEGORY =           15
# INITIALIZE THREE Noah LSM RELATED TABLES
# Skipping over LUTYPE = USGS
#  LANDUSE TYPE = MODIFIED_IGBP_MODIS_NOAH FOUND          20  CATEGORIES
#  INPUT SOIL TEXTURE CLASSIFICATION = STAS
#  SOIL TEXTURE CLASSIFICATION = STAS FOUND          19  CATEGORIES
# Max map factor in domain 1 =  0.99. Scale the dt in the model accordingly.
#  D01: Time step                              =    30.0000000      (s)
#  D01: Grid Distance                          =    10.0000000      (km)
#  D01: Grid Distance Ratio dt/dx              =    3.00000000      (s/km)
#  D01: Ratio Including Maximum Map Factor     =    2.96027613      (s/km)
#  D01: NML defined reasonable_time_step_ratio =    6.00000000
#  Climate GHG input from file from year         1765  to         2499
#  CO2   range =    277.91300000000001        579.26400000000001       ppm
#  N2O   range =    274.37200000000001        359.79800000000000       ppb
#  CH4   range =    738.98599999999999        997.31100000000004       ppb
#  CFC11 range =    0.0000000000000000        1.4000000000000000E-002  ppt
#  CFC12 range =    0.0000000000000000        2.8809999999999998       ppt
#  Normal ending of CAMtr_volume_mixing_ratio file
#  GHG annual values from CAM trace gas file
#  Year =         2023 , Julian day =            1
#  CO2   =    4.2180985372190533E-004  volume mixing ratio
#  N2O   =    3.3404662616691106E-007  volume mixing ratio
#  CH4   =    1.9375017123011811E-006  volume mixing ratio
#  CFC11 =    2.1122290601253179E-010  volume mixing ratio
#  CFC12 =    4.8310399534210311E-010  volume mixing ratio
# INPUT LandUse = "MODIFIED_IGBP_MODIS_NOAH"
#  LANDUSE TYPE = "MODIFIED_IGBP_MODIS_NOAH" FOUND          61  CATEGORIES           2  SEASONS WATER CATEGORY =           17  SNOW CATEGORY =           15
# INITIALIZE THREE Noah LSM RELATED TABLES
# Skipping over LUTYPE = USGS
#  LANDUSE TYPE = MODIFIED_IGBP_MODIS_NOAH FOUND          20  CATEGORIES
#  INPUT SOIL TEXTURE CLASSIFICATION = STAS
#  SOIL TEXTURE CLASSIFICATION = STAS FOUND          19  CATEGORIES
#  mediation_integrate.G        1242 DATASET=HISTORY
#  mediation_integrate.G        1243  grid%id            1  grid%oid            1
# Timing for Writing wrfout_d01_2023-01-01_00:00:00 for domain        1:    0.13823 elapsed seconds
# d01 2023-01-01_00:00:00  Input data is acceptable to use: wrfbdy_d01
# Timing for processing lateral boundary for domain        1:    0.03668 elapsed seconds
#  Tile Strategy is not specified. Assuming 1D-Y
# WRF TILE   1 IS      1 IE     50 JS      1 JE     50
# WRF NUMBER OF TILES =   1
# d01 2023-01-01_00:00:00  ----------------------------------------
# d01 2023-01-01_00:00:00  W-DAMPING  BEGINS AT W-COURANT NUMBER =    1.00000000
# d01 2023-01-01_00:00:00  ----------------------------------------
#  mediation_integrate.G        1242 DATASET=HISTORY
#  mediation_integrate.G        1243  grid%id            2  grid%oid            2
# Timing for Writing wrfout_d02_2023-01-01_00:00:00 for domain        2:    0.13014 elapsed seconds
#  Tile Strategy is not specified. Assuming 1D-Y
# WRF TILE   1 IS      1 IE     51 JS      1 JE     51
# WRF NUMBER OF TILES =   1
# Timing for main: time 2023-01-01_00:00:06 on domain   2:    1.72027 elapsed seconds
# Timing for main: time 2023-01-01_00:00:12 on domain   2:    0.12251 elapsed seconds
# Timing for main: time 2023-01-01_00:00:18 on domain   2:    0.11868 elapsed seconds
# Timing for main: time 2023-01-01_00:00:24 on domain   2:    0.11152 elapsed seconds
# Timing for main: time 2023-01-01_00:00:30 on domain   2:    0.11101 elapsed seconds
# Timing for main: time 2023-01-01_00:00:30 on domain   1:    5.11070 elapsed seconds
# Timing for main: time 2023-01-01_00:00:36 on domain   2:    0.10559 elapsed seconds
# Timing for main: time 2023-01-01_00:00:42 on domain   2:    0.10498 elapsed seconds
# Timing for main: time 2023-01-01_00:00:48 on domain   2:    0.10546 elapsed seconds
# Timing for main: time 2023-01-01_00:00:54 on domain   2:    0.11997 elapsed seconds
# Timing for main: time 2023-01-01_00:01:00 on domain   2:    0.11245 elapsed seconds
# Timing for main: time 2023-01-01_00:01:00 on domain   1:    0.84998 elapsed seconds
# Timing for main: time 2023-01-01_00:01:06 on domain   2:    0.11113 elapsed seconds
# Timing for main: time 2023-01-01_00:01:12 on domain   2:    0.11980 elapsed seconds
# Timing for main: time 2023-01-01_00:01:18 on domain   2:    0.11077 elapsed seconds
# Timing for main: time 2023-01-01_00:01:24 on domain   2:    0.11174 elapsed seconds
# Timing for main: time 2023-01-01_00:01:30 on domain   2:    0.11072 elapsed seconds
# Timing for main: time 2023-01-01_00:01:30 on domain   1:    0.87058 elapsed seconds
# Timing for main: time 2023-01-01_00:01:36 on domain   2:    0.11134 elapsed seconds
# Timing for main: time 2023-01-01_00:01:42 on domain   2:    0.11391 elapsed seconds
# Timing for main: time 2023-01-01_00:01:48 on domain   2:    0.11319 elapsed seconds
# Timing for main: time 2023-01-01_00:01:54 on domain   2:    0.11172 elapsed seconds
# Timing for main: time 2023-01-01_00:02:00 on domain   2:    0.11164 elapsed seconds
# Timing for main: time 2023-01-01_00:02:00 on domain   1:    0.86384 elapsed seconds
# Timing for main: time 2023-01-01_00:02:06 on domain   2:    0.11172 elapsed seconds
# Timing for main: time 2023-01-01_00:02:12 on domain   2:    0.11310 elapsed seconds
# Timing for main: time 2023-01-01_00:02:18 on domain   2:    0.11298 elapsed seconds
# Timing for main: time 2023-01-01_00:02:24 on domain   2:    0.10974 elapsed seconds
# Timing for main: time 2023-01-01_00:02:30 on domain   2:    0.10746 elapsed seconds
# Timing for main: time 2023-01-01_00:02:30 on domain   1:    0.85870 elapsed seconds
# Timing for main: time 2023-01-01_00:02:36 on domain   2:    0.11120 elapsed seconds
# Timing for main: time 2023-01-01_00:02:42 on domain   2:    0.11091 elapsed seconds
# Timing for main: time 2023-01-01_00:02:48 on domain   2:    0.11178 elapsed seconds
# Timing for main: time 2023-01-01_00:02:54 on domain   2:    0.12097 elapsed seconds
# Timing for main: time 2023-01-01_00:03:00 on domain   2:    0.12490 elapsed seconds
# Timing for main: time 2023-01-01_00:03:00 on domain   1:    0.89062 elapsed seconds
# Timing for main: time 2023-01-01_00:03:06 on domain   2:    0.11241 elapsed seconds
# Timing for main: time 2023-01-01_00:03:12 on domain   2:    0.11207 elapsed seconds
# Timing for main: time 2023-01-01_00:03:18 on domain   2:    0.11329 elapsed seconds
# Timing for main: time 2023-01-01_00:03:24 on domain   2:    0.11214 elapsed seconds
# Timing for main: time 2023-01-01_00:03:30 on domain   2:    0.14438 elapsed seconds
# Timing for main: time 2023-01-01_00:03:30 on domain   1:    0.90752 elapsed seconds
# Timing for main: time 2023-01-01_00:03:36 on domain   2:    0.11943 elapsed seconds
# Timing for main: time 2023-01-01_00:03:42 on domain   2:    0.51812 elapsed seconds
# Timing for main: time 2023-01-01_00:03:48 on domain   2:    0.26122 elapsed seconds
# Timing for main: time 2023-01-01_00:03:54 on domain   2:    0.13736 elapsed seconds
# Timing for main: time 2023-01-01_00:04:00 on domain   2:    0.11925 elapsed seconds
# Timing for main: time 2023-01-01_00:04:00 on domain   1:    1.59518 elapsed seconds
# Timing for main: time 2023-01-01_00:04:06 on domain   2:    0.10622 elapsed seconds
# Timing for main: time 2023-01-01_00:04:12 on domain   2:    0.11299 elapsed seconds
# Timing for main: time 2023-01-01_00:04:18 on domain   2:    0.11310 elapsed seconds
# Timing for main: time 2023-01-01_00:04:24 on domain   2:    0.11338 elapsed seconds
# Timing for main: time 2023-01-01_00:04:30 on domain   2:    0.11167 elapsed seconds
# Timing for main: time 2023-01-01_00:04:30 on domain   1:    0.88332 elapsed seconds
# Timing for main: time 2023-01-01_00:04:36 on domain   2:    0.11312 elapsed seconds
# Timing for main: time 2023-01-01_00:04:42 on domain   2:    0.11162 elapsed seconds
# Timing for main: time 2023-01-01_00:04:48 on domain   2:    0.11259 elapsed seconds
# Timing for main: time 2023-01-01_00:04:54 on domain   2:    0.11131 elapsed seconds
# Timing for main: time 2023-01-01_00:05:00 on domain   2:    0.11921 elapsed seconds
# Timing for main: time 2023-01-01_00:05:00 on domain   1:    0.87141 elapsed seconds
# Timing for main: time 2023-01-01_00:05:06 on domain   2:    0.11126 elapsed seconds
# Timing for main: time 2023-01-01_00:05:12 on domain   2:    0.11215 elapsed seconds
# Timing for main: time 2023-01-01_00:05:18 on domain   2:    0.11149 elapsed seconds
# Timing for main: time 2023-01-01_00:05:24 on domain   2:    0.12310 elapsed seconds
# Timing for main: time 2023-01-01_00:05:30 on domain   2:    0.11233 elapsed seconds
# Timing for main: time 2023-01-01_00:05:30 on domain   1:    0.87243 elapsed seconds
# Timing for main: time 2023-01-01_00:05:36 on domain   2:    0.10747 elapsed seconds
# Timing for main: time 2023-01-01_00:05:42 on domain   2:    0.10752 elapsed seconds
# Timing for main: time 2023-01-01_00:05:48 on domain   2:    0.10751 elapsed seconds
# Timing for main: time 2023-01-01_00:05:54 on domain   2:    0.10941 elapsed seconds
# Timing for main: time 2023-01-01_00:06:00 on domain   2:    0.11142 elapsed seconds
# Timing for main: time 2023-01-01_00:06:00 on domain   1:    0.85076 elapsed seconds
# Timing for main: time 2023-01-01_00:06:06 on domain   2:    0.11053 elapsed seconds
# Timing for main: time 2023-01-01_00:06:12 on domain   2:    0.11290 elapsed seconds
# Timing for main: time 2023-01-01_00:06:18 on domain   2:    0.11364 elapsed seconds
# Timing for main: time 2023-01-01_00:06:24 on domain   2:    0.11215 elapsed seconds
# Timing for main: time 2023-01-01_00:06:30 on domain   2:    0.11191 elapsed seconds
# Timing for main: time 2023-01-01_00:06:30 on domain   1:    0.87095 elapsed seconds
# Timing for main: time 2023-01-01_00:06:36 on domain   2:    0.11740 elapsed seconds
# Timing for main: time 2023-01-01_00:06:42 on domain   2:    0.15213 elapsed seconds
# Timing for main: time 2023-01-01_00:06:48 on domain   2:    0.53645 elapsed seconds
# Timing for main: time 2023-01-01_00:06:54 on domain   2:    0.11421 elapsed seconds
# Timing for main: time 2023-01-01_00:07:00 on domain   2:    0.17166 elapsed seconds
# Timing for main: time 2023-01-01_00:07:00 on domain   1:    1.55133 elapsed seconds
# Timing for main: time 2023-01-01_00:07:06 on domain   2:    0.11245 elapsed seconds
# Timing for main: time 2023-01-01_00:07:12 on domain   2:    0.11129 elapsed seconds
# Timing for main: time 2023-01-01_00:07:18 on domain   2:    0.11255 elapsed seconds
# Timing for main: time 2023-01-01_00:07:24 on domain   2:    0.11271 elapsed seconds
# Timing for main: time 2023-01-01_00:07:30 on domain   2:    0.13040 elapsed seconds
# Timing for main: time 2023-01-01_00:07:30 on domain   1:    0.91487 elapsed seconds
# Timing for main: time 2023-01-01_00:07:36 on domain   2:    0.12205 elapsed seconds
# Timing for main: time 2023-01-01_00:07:42 on domain   2:    0.12447 elapsed seconds
# Timing for main: time 2023-01-01_00:07:48 on domain   2:    0.12341 elapsed seconds
# Timing for main: time 2023-01-01_00:07:54 on domain   2:    0.11168 elapsed seconds
# Timing for main: time 2023-01-01_00:08:00 on domain   2:    0.10723 elapsed seconds
# Timing for main: time 2023-01-01_00:08:00 on domain   1:    0.90953 elapsed seconds
# Timing for main: time 2023-01-01_00:08:06 on domain   2:    0.10638 elapsed seconds
# Timing for main: time 2023-01-01_00:08:12 on domain   2:    0.10666 elapsed seconds
# Timing for main: time 2023-01-01_00:08:18 on domain   2:    0.10679 elapsed seconds
# Timing for main: time 2023-01-01_00:08:24 on domain   2:    0.10634 elapsed seconds
# Timing for main: time 2023-01-01_00:08:30 on domain   2:    0.10798 elapsed seconds
# Timing for main: time 2023-01-01_00:08:30 on domain   1:    0.84435 elapsed seconds
# Timing for main: time 2023-01-01_00:08:36 on domain   2:    0.11352 elapsed seconds
# Timing for main: time 2023-01-01_00:08:42 on domain   2:    0.11186 elapsed seconds
# Timing for main: time 2023-01-01_00:08:48 on domain   2:    0.11304 elapsed seconds
# Timing for main: time 2023-01-01_00:08:54 on domain   2:    0.11017 elapsed seconds
# Timing for main: time 2023-01-01_00:09:00 on domain   2:    0.11225 elapsed seconds
# Timing for main: time 2023-01-01_00:09:00 on domain   1:    0.86926 elapsed seconds
# Timing for main: time 2023-01-01_00:09:06 on domain   2:    0.10734 elapsed seconds
# Timing for main: time 2023-01-01_00:09:12 on domain   2:    0.10697 elapsed seconds
# Timing for main: time 2023-01-01_00:09:18 on domain   2:    0.10701 elapsed seconds
# Timing for main: time 2023-01-01_00:09:24 on domain   2:    0.10581 elapsed seconds
# Timing for main: time 2023-01-01_00:09:30 on domain   2:    0.10973 elapsed seconds
# Timing for main: time 2023-01-01_00:09:30 on domain   1:    0.83830 elapsed seconds
# Timing for main: time 2023-01-01_00:09:36 on domain   2:    0.11812 elapsed seconds
# Timing for main: time 2023-01-01_00:09:42 on domain   2:    0.11462 elapsed seconds
# Timing for main: time 2023-01-01_00:09:48 on domain   2:    0.10653 elapsed seconds
# Timing for main: time 2023-01-01_00:09:54 on domain   2:    0.10926 elapsed seconds
# Timing for main: time 2023-01-01_00:10:00 on domain   2:    0.11386 elapsed seconds
# Timing for main: time 2023-01-01_00:10:00 on domain   1:    0.89907 elapsed seconds
# Timing for main: time 2023-01-01_00:10:06 on domain   2:    0.10742 elapsed seconds
# Timing for main: time 2023-01-01_00:10:12 on domain   2:    0.10775 elapsed seconds
# Timing for main: time 2023-01-01_00:10:18 on domain   2:    0.10730 elapsed seconds
# Timing for main: time 2023-01-01_00:10:24 on domain   2:    0.10813 elapsed seconds
# Timing for main: time 2023-01-01_00:10:30 on domain   2:    0.10760 elapsed seconds
# Timing for main: time 2023-01-01_00:10:30 on domain   1:    0.86096 elapsed seconds
# Timing for main: time 2023-01-01_00:10:36 on domain   2:    0.10648 elapsed seconds
# Timing for main: time 2023-01-01_00:10:42 on domain   2:    0.12096 elapsed seconds
# Timing for main: time 2023-01-01_00:10:48 on domain   2:    0.15736 elapsed seconds
# Timing for main: time 2023-01-01_00:10:54 on domain   2:    0.11543 elapsed seconds
# Timing for main: time 2023-01-01_00:11:00 on domain   2:    0.11110 elapsed seconds
# Timing for main: time 2023-01-01_00:11:00 on domain   1:    0.91358 elapsed seconds
# Timing for main: time 2023-01-01_00:11:06 on domain   2:    0.11587 elapsed seconds
# Timing for main: time 2023-01-01_00:11:12 on domain   2:    0.11246 elapsed seconds
# Timing for main: time 2023-01-01_00:11:18 on domain   2:    0.11206 elapsed seconds
# Timing for main: time 2023-01-01_00:11:24 on domain   2:    0.11436 elapsed seconds
# Timing for main: time 2023-01-01_00:11:30 on domain   2:    0.11143 elapsed seconds
# Timing for main: time 2023-01-01_00:11:30 on domain   1:    0.91941 elapsed seconds
# Timing for main: time 2023-01-01_00:11:36 on domain   2:    0.11428 elapsed seconds
# Timing for main: time 2023-01-01_00:11:42 on domain   2:    0.10729 elapsed seconds
# Timing for main: time 2023-01-01_00:11:48 on domain   2:    0.11271 elapsed seconds
# Timing for main: time 2023-01-01_00:11:54 on domain   2:    0.11335 elapsed seconds
# Timing for main: time 2023-01-01_00:12:00 on domain   2:    0.10988 elapsed seconds
# Timing for main: time 2023-01-01_00:12:00 on domain   1:    0.86451 elapsed seconds
# Timing for main: time 2023-01-01_00:12:06 on domain   2:    0.11604 elapsed seconds
# Timing for main: time 2023-01-01_00:12:12 on domain   2:    0.11205 elapsed seconds
# Timing for main: time 2023-01-01_00:12:18 on domain   2:    0.11478 elapsed seconds
# Timing for main: time 2023-01-01_00:12:24 on domain   2:    0.11684 elapsed seconds
# Timing for main: time 2023-01-01_00:12:30 on domain   2:    0.11121 elapsed seconds
# Timing for main: time 2023-01-01_00:12:30 on domain   1:    0.87967 elapsed seconds
# Timing for main: time 2023-01-01_00:12:36 on domain   2:    0.10868 elapsed seconds
# Timing for main: time 2023-01-01_00:12:42 on domain   2:    0.11872 elapsed seconds
# Timing for main: time 2023-01-01_00:12:48 on domain   2:    0.10856 elapsed seconds
# Timing for main: time 2023-01-01_00:12:54 on domain   2:    0.10702 elapsed seconds
# Timing for main: time 2023-01-01_00:13:00 on domain   2:    0.10859 elapsed seconds
# Timing for main: time 2023-01-01_00:13:00 on domain   1:    0.86493 elapsed seconds
# Timing for main: time 2023-01-01_00:13:06 on domain   2:    0.14981 elapsed seconds
# Timing for main: time 2023-01-01_00:13:12 on domain   2:    0.13057 elapsed seconds
# Timing for main: time 2023-01-01_00:13:18 on domain   2:    0.12081 elapsed seconds
# Timing for main: time 2023-01-01_00:13:24 on domain   2:    0.11315 elapsed seconds
# Timing for main: time 2023-01-01_00:13:30 on domain   2:    0.10881 elapsed seconds
# Timing for main: time 2023-01-01_00:13:30 on domain   1:    0.99948 elapsed seconds
# Timing for main: time 2023-01-01_00:13:36 on domain   2:    0.15932 elapsed seconds
# Timing for main: time 2023-01-01_00:13:42 on domain   2:    0.30562 elapsed seconds
# Timing for main: time 2023-01-01_00:13:48 on domain   2:    0.27025 elapsed seconds
# Timing for main: time 2023-01-01_00:13:54 on domain   2:    0.11421 elapsed seconds
# Timing for main: time 2023-01-01_00:14:00 on domain   2:    0.11827 elapsed seconds
# Timing for main: time 2023-01-01_00:14:00 on domain   1:    1.28434 elapsed seconds
# Timing for main: time 2023-01-01_00:14:06 on domain   2:    0.11177 elapsed seconds
# Timing for main: time 2023-01-01_00:14:12 on domain   2:    0.11706 elapsed seconds
# Timing for main: time 2023-01-01_00:14:18 on domain   2:    0.14584 elapsed seconds
# Timing for main: time 2023-01-01_00:14:24 on domain   2:    0.13767 elapsed seconds
# Timing for main: time 2023-01-01_00:14:30 on domain   2:    0.13818 elapsed seconds
# Timing for main: time 2023-01-01_00:14:30 on domain   1:    0.97303 elapsed seconds
# Timing for main: time 2023-01-01_00:14:36 on domain   2:    0.14845 elapsed seconds
# Timing for main: time 2023-01-01_00:14:42 on domain   2:    0.14526 elapsed seconds
# Timing for main: time 2023-01-01_00:14:48 on domain   2:    0.14334 elapsed seconds
# Timing for main: time 2023-01-01_00:14:54 on domain   2:    0.11648 elapsed seconds
# Timing for main: time 2023-01-01_00:15:00 on domain   2:    0.11648 elapsed seconds
# Timing for main: time 2023-01-01_00:15:00 on domain   1:    0.98310 elapsed seconds
# Timing for main: time 2023-01-01_00:15:06 on domain   2:    1.66632 elapsed seconds
# Timing for main: time 2023-01-01_00:15:12 on domain   2:    0.11346 elapsed seconds
# Timing for main: time 2023-01-01_00:15:18 on domain   2:    0.11198 elapsed seconds
# Timing for main: time 2023-01-01_00:15:24 on domain   2:    0.11175 elapsed seconds
# Timing for main: time 2023-01-01_00:15:30 on domain   2:    0.12076 elapsed seconds
# Timing for main: time 2023-01-01_00:15:30 on domain   1:    3.91718 elapsed seconds
# Timing for main: time 2023-01-01_00:15:36 on domain   2:    0.19444 elapsed seconds
# Timing for main: time 2023-01-01_00:15:42 on domain   2:    0.21372 elapsed seconds
# Timing for main: time 2023-01-01_00:15:48 on domain   2:    0.12253 elapsed seconds
# Timing for main: time 2023-01-01_00:15:54 on domain   2:    0.12334 elapsed seconds
# Timing for main: time 2023-01-01_00:16:00 on domain   2:    0.12469 elapsed seconds
# Timing for main: time 2023-01-01_00:16:00 on domain   1:    1.09207 elapsed seconds
# Timing for main: time 2023-01-01_00:16:06 on domain   2:    0.56595 elapsed seconds
# Timing for main: time 2023-01-01_00:16:12 on domain   2:    0.14615 elapsed seconds
# Timing for main: time 2023-01-01_00:16:18 on domain   2:    0.13023 elapsed seconds
# Timing for main: time 2023-01-01_00:16:24 on domain   2:    0.13601 elapsed seconds
# Timing for main: time 2023-01-01_00:16:30 on domain   2:    0.12033 elapsed seconds
# Timing for main: time 2023-01-01_00:16:30 on domain   1:    1.54466 elapsed seconds
# Timing for main: time 2023-01-01_00:16:36 on domain   2:    0.11870 elapsed seconds
# Timing for main: time 2023-01-01_00:16:42 on domain   2:    0.11219 elapsed seconds
# Timing for main: time 2023-01-01_00:16:48 on domain   2:    0.11404 elapsed seconds
# Timing for main: time 2023-01-01_00:16:54 on domain   2:    0.11243 elapsed seconds
# Timing for main: time 2023-01-01_00:17:00 on domain   2:    0.11402 elapsed seconds
# Timing for main: time 2023-01-01_00:17:00 on domain   1:    0.92092 elapsed seconds
# Timing for main: time 2023-01-01_00:17:06 on domain   2:    0.12988 elapsed seconds
# Timing for main: time 2023-01-01_00:17:12 on domain   2:    0.12000 elapsed seconds
# Timing for main: time 2023-01-01_00:17:18 on domain   2:    0.12660 elapsed seconds
# Timing for main: time 2023-01-01_00:17:24 on domain   2:    0.12295 elapsed seconds
# Timing for main: time 2023-01-01_00:17:30 on domain   2:    0.11499 elapsed seconds
# Timing for main: time 2023-01-01_00:17:30 on domain   1:    0.95026 elapsed seconds
# Timing for main: time 2023-01-01_00:17:36 on domain   2:    0.11651 elapsed seconds
# Timing for main: time 2023-01-01_00:17:42 on domain   2:    0.12740 elapsed seconds
# Timing for main: time 2023-01-01_00:17:48 on domain   2:    0.12712 elapsed seconds
# Timing for main: time 2023-01-01_00:17:54 on domain   2:    0.12923 elapsed seconds
# Timing for main: time 2023-01-01_00:18:00 on domain   2:    0.12817 elapsed seconds
# Timing for main: time 2023-01-01_00:18:00 on domain   1:    0.94291 elapsed seconds
# Timing for main: time 2023-01-01_00:18:06 on domain   2:    0.11980 elapsed seconds
# Timing for main: time 2023-01-01_00:18:12 on domain   2:    0.12219 elapsed seconds
# Timing for main: time 2023-01-01_00:18:18 on domain   2:    0.12516 elapsed seconds
# Timing for main: time 2023-01-01_00:18:24 on domain   2:    0.12965 elapsed seconds
# Timing for main: time 2023-01-01_00:18:30 on domain   2:    0.13075 elapsed seconds
# Timing for main: time 2023-01-01_00:18:30 on domain   1:    0.95659 elapsed seconds
# Timing for main: time 2023-01-01_00:18:36 on domain   2:    0.12589 elapsed seconds
# Timing for main: time 2023-01-01_00:18:42 on domain   2:    0.12156 elapsed seconds
# Timing for main: time 2023-01-01_00:18:48 on domain   2:    0.12662 elapsed seconds
# Timing for main: time 2023-01-01_00:18:54 on domain   2:    0.12579 elapsed seconds
# Timing for main: time 2023-01-01_00:19:00 on domain   2:    0.14054 elapsed seconds
# Timing for main: time 2023-01-01_00:19:00 on domain   1:    0.97867 elapsed seconds
# Timing for main: time 2023-01-01_00:19:06 on domain   2:    0.12318 elapsed seconds
# Timing for main: time 2023-01-01_00:19:12 on domain   2:    0.14091 elapsed seconds
# Timing for main: time 2023-01-01_00:19:18 on domain   2:    0.15218 elapsed seconds
# Timing for main: time 2023-01-01_00:19:24 on domain   2:    0.13580 elapsed seconds
# Timing for main: time 2023-01-01_00:19:30 on domain   2:    0.13626 elapsed seconds
# Timing for main: time 2023-01-01_00:19:30 on domain   1:    1.04747 elapsed seconds
# Timing for main: time 2023-01-01_00:19:36 on domain   2:    0.12308 elapsed seconds
# Timing for main: time 2023-01-01_00:19:42 on domain   2:    0.11697 elapsed seconds
# Timing for main: time 2023-01-01_00:19:48 on domain   2:    0.12593 elapsed seconds
# Timing for main: time 2023-01-01_00:19:54 on domain   2:    0.13714 elapsed seconds
# Timing for main: time 2023-01-01_00:20:00 on domain   2:    0.12143 elapsed seconds
# Timing for main: time 2023-01-01_00:20:00 on domain   1:    0.96902 elapsed seconds
# Timing for main: time 2023-01-01_00:20:06 on domain   2:    0.12214 elapsed seconds
# Timing for main: time 2023-01-01_00:20:12 on domain   2:    0.12589 elapsed seconds
# Timing for main: time 2023-01-01_00:20:18 on domain   2:    0.12098 elapsed seconds
# Timing for main: time 2023-01-01_00:20:24 on domain   2:    0.12864 elapsed seconds
# Timing for main: time 2023-01-01_00:20:30 on domain   2:    0.13249 elapsed seconds
# Timing for main: time 2023-01-01_00:20:30 on domain   1:    0.96234 elapsed seconds
# Timing for main: time 2023-01-01_00:20:36 on domain   2:    0.12558 elapsed seconds
# Timing for main: time 2023-01-01_00:20:42 on domain   2:    0.12088 elapsed seconds
# Timing for main: time 2023-01-01_00:20:48 on domain   2:    0.12927 elapsed seconds
# Timing for main: time 2023-01-01_00:20:54 on domain   2:    0.12585 elapsed seconds
# Timing for main: time 2023-01-01_00:21:00 on domain   2:    0.13878 elapsed seconds
# Timing for main: time 2023-01-01_00:21:00 on domain   1:    0.96705 elapsed seconds
# Timing for main: time 2023-01-01_00:21:06 on domain   2:    0.12888 elapsed seconds
# Timing for main: time 2023-01-01_00:21:12 on domain   2:    0.14608 elapsed seconds
# Timing for main: time 2023-01-01_00:21:18 on domain   2:    0.12719 elapsed seconds
# Timing for main: time 2023-01-01_00:21:24 on domain   2:    0.12711 elapsed seconds
# Timing for main: time 2023-01-01_00:21:30 on domain   2:    0.12402 elapsed seconds
# Timing for main: time 2023-01-01_00:21:30 on domain   1:    0.99271 elapsed seconds
# Timing for main: time 2023-01-01_00:21:36 on domain   2:    0.12091 elapsed seconds
# Timing for main: time 2023-01-01_00:21:42 on domain   2:    0.14714 elapsed seconds
# Timing for main: time 2023-01-01_00:21:48 on domain   2:    0.13689 elapsed seconds
# Timing for main: time 2023-01-01_00:21:54 on domain   2:    0.13492 elapsed seconds
# Timing for main: time 2023-01-01_00:22:00 on domain   2:    0.14070 elapsed seconds
# Timing for main: time 2023-01-01_00:22:00 on domain   1:    1.01823 elapsed seconds
# Timing for main: time 2023-01-01_00:22:06 on domain   2:    0.15475 elapsed seconds
# Timing for main: time 2023-01-01_00:22:12 on domain   2:    0.17774 elapsed seconds
# Timing for main: time 2023-01-01_00:22:18 on domain   2:    0.15064 elapsed seconds
# Timing for main: time 2023-01-01_00:22:24 on domain   2:    0.15870 elapsed seconds
# Timing for main: time 2023-01-01_00:22:30 on domain   2:    0.12253 elapsed seconds
# Timing for main: time 2023-01-01_00:22:30 on domain   1:    1.39043 elapsed seconds
# Timing for main: time 2023-01-01_00:22:36 on domain   2:    0.11865 elapsed seconds
# Timing for main: time 2023-01-01_00:22:42 on domain   2:    0.11871 elapsed seconds
# Timing for main: time 2023-01-01_00:22:48 on domain   2:    0.12257 elapsed seconds
# Timing for main: time 2023-01-01_00:22:54 on domain   2:    0.29769 elapsed seconds
# Timing for main: time 2023-01-01_00:23:00 on domain   2:    0.13195 elapsed seconds
# Timing for main: time 2023-01-01_00:23:00 on domain   1:    1.13329 elapsed seconds
# Timing for main: time 2023-01-01_00:23:06 on domain   2:    0.13576 elapsed seconds
# Timing for main: time 2023-01-01_00:23:12 on domain   2:    0.37817 elapsed seconds
# Timing for main: time 2023-01-01_00:23:18 on domain   2:    0.35683 elapsed seconds
# Timing for main: time 2023-01-01_00:23:24 on domain   2:    0.14569 elapsed seconds
# Timing for main: time 2023-01-01_00:23:30 on domain   2:    0.13779 elapsed seconds
# Timing for main: time 2023-01-01_00:23:30 on domain   1:    1.47639 elapsed seconds
# Timing for main: time 2023-01-01_00:23:36 on domain   2:    0.30537 elapsed seconds
# Timing for main: time 2023-01-01_00:23:42 on domain   2:    0.22673 elapsed seconds
# Timing for main: time 2023-01-01_00:23:48 on domain   2:    0.18607 elapsed seconds
# Timing for main: time 2023-01-01_00:23:54 on domain   2:    0.44409 elapsed seconds
# Timing for main: time 2023-01-01_00:24:00 on domain   2:    0.44456 elapsed seconds
# Timing for main: time 2023-01-01_00:24:00 on domain   1:    1.96833 elapsed seconds
# Timing for main: time 2023-01-01_00:24:06 on domain   2:    0.13901 elapsed seconds
# Timing for main: time 2023-01-01_00:24:12 on domain   2:    0.14772 elapsed seconds
# Timing for main: time 2023-01-01_00:24:18 on domain   2:    0.24545 elapsed seconds
# Timing for main: time 2023-01-01_00:24:24 on domain   2:    0.14343 elapsed seconds
# Timing for main: time 2023-01-01_00:24:30 on domain   2:    0.15005 elapsed seconds
# Timing for main: time 2023-01-01_00:24:30 on domain   1:    1.24806 elapsed seconds
# Timing for main: time 2023-01-01_00:24:36 on domain   2:    0.14024 elapsed seconds
# Timing for main: time 2023-01-01_00:24:42 on domain   2:    0.13757 elapsed seconds
# Timing for main: time 2023-01-01_00:24:48 on domain   2:    0.14020 elapsed seconds
# Timing for main: time 2023-01-01_00:24:54 on domain   2:    0.12794 elapsed seconds
# Timing for main: time 2023-01-01_00:25:00 on domain   2:    0.12716 elapsed seconds
# Timing for main: time 2023-01-01_00:25:00 on domain   1:    1.03279 elapsed seconds
# Timing for main: time 2023-01-01_00:25:06 on domain   2:    0.11170 elapsed seconds
# Timing for main: time 2023-01-01_00:25:12 on domain   2:    0.12559 elapsed seconds
# Timing for main: time 2023-01-01_00:25:18 on domain   2:    0.11759 elapsed seconds
# Timing for main: time 2023-01-01_00:25:24 on domain   2:    0.12521 elapsed seconds
# Timing for main: time 2023-01-01_00:25:30 on domain   2:    0.14194 elapsed seconds
# Timing for main: time 2023-01-01_00:25:30 on domain   1:    0.95006 elapsed seconds
# Timing for main: time 2023-01-01_00:25:36 on domain   2:    0.12224 elapsed seconds
# Timing for main: time 2023-01-01_00:25:42 on domain   2:    0.13199 elapsed seconds
# Timing for main: time 2023-01-01_00:25:48 on domain   2:    0.12675 elapsed seconds
# Timing for main: time 2023-01-01_00:25:54 on domain   2:    0.11474 elapsed seconds
# Timing for main: time 2023-01-01_00:26:00 on domain   2:    0.11365 elapsed seconds
# Timing for main: time 2023-01-01_00:26:00 on domain   1:    0.93468 elapsed seconds
# Timing for main: time 2023-01-01_00:26:06 on domain   2:    0.11257 elapsed seconds
# Timing for main: time 2023-01-01_00:26:12 on domain   2:    0.11542 elapsed seconds
# Timing for main: time 2023-01-01_00:26:18 on domain   2:    0.11275 elapsed seconds
# Timing for main: time 2023-01-01_00:26:24 on domain   2:    0.13141 elapsed seconds
# Timing for main: time 2023-01-01_00:26:30 on domain   2:    0.12509 elapsed seconds
# Timing for main: time 2023-01-01_00:26:30 on domain   1:    0.92064 elapsed seconds
# Timing for main: time 2023-01-01_00:26:36 on domain   2:    0.10898 elapsed seconds
# Timing for main: time 2023-01-01_00:26:42 on domain   2:    0.11483 elapsed seconds
# Timing for main: time 2023-01-01_00:26:48 on domain   2:    0.10855 elapsed seconds
# Timing for main: time 2023-01-01_00:26:54 on domain   2:    0.11492 elapsed seconds
# Timing for main: time 2023-01-01_00:27:00 on domain   2:    0.10981 elapsed seconds
# Timing for main: time 2023-01-01_00:27:00 on domain   1:    0.87639 elapsed seconds
# Timing for main: time 2023-01-01_00:27:06 on domain   2:    0.12587 elapsed seconds
# Timing for main: time 2023-01-01_00:27:12 on domain   2:    0.11681 elapsed seconds
# Timing for main: time 2023-01-01_00:27:18 on domain   2:    0.12828 elapsed seconds
# Timing for main: time 2023-01-01_00:27:24 on domain   2:    0.11691 elapsed seconds
# Timing for main: time 2023-01-01_00:27:30 on domain   2:    0.11294 elapsed seconds
# Timing for main: time 2023-01-01_00:27:30 on domain   1:    0.92370 elapsed seconds
# Timing for main: time 2023-01-01_00:27:36 on domain   2:    0.11521 elapsed seconds
# Timing for main: time 2023-01-01_00:27:42 on domain   2:    0.11633 elapsed seconds
# Timing for main: time 2023-01-01_00:27:48 on domain   2:    0.11888 elapsed seconds
# Timing for main: time 2023-01-01_00:27:54 on domain   2:    0.12170 elapsed seconds
# Timing for main: time 2023-01-01_00:28:00 on domain   2:    0.11672 elapsed seconds
# Timing for main: time 2023-01-01_00:28:00 on domain   1:    0.90504 elapsed seconds
# Timing for main: time 2023-01-01_00:28:06 on domain   2:    0.13256 elapsed seconds
# Timing for main: time 2023-01-01_00:28:12 on domain   2:    0.13705 elapsed seconds
# Timing for main: time 2023-01-01_00:28:18 on domain   2:    0.17963 elapsed seconds
# Timing for main: time 2023-01-01_00:28:24 on domain   2:    0.29141 elapsed seconds
# Timing for main: time 2023-01-01_00:28:30 on domain   2:    0.20213 elapsed seconds
# Timing for main: time 2023-01-01_00:28:30 on domain   1:    1.31911 elapsed seconds
# Timing for main: time 2023-01-01_00:28:36 on domain   2:    0.16398 elapsed seconds
# Timing for main: time 2023-01-01_00:28:42 on domain   2:    0.12687 elapsed seconds
# Timing for main: time 2023-01-01_00:28:48 on domain   2:    0.15490 elapsed seconds
# Timing for main: time 2023-01-01_00:28:54 on domain   2:    0.31818 elapsed seconds
# Timing for main: time 2023-01-01_00:29:00 on domain   2:    0.38362 elapsed seconds
# Timing for main: time 2023-01-01_00:29:00 on domain   1:    1.49765 elapsed seconds
# Timing for main: time 2023-01-01_00:29:06 on domain   2:    0.13585 elapsed seconds
# Timing for main: time 2023-01-01_00:29:12 on domain   2:    0.12886 elapsed seconds
# Timing for main: time 2023-01-01_00:29:18 on domain   2:    0.12988 elapsed seconds
# Timing for main: time 2023-01-01_00:29:24 on domain   2:    0.13762 elapsed seconds
# Timing for main: time 2023-01-01_00:29:30 on domain   2:    0.13501 elapsed seconds
# Timing for main: time 2023-01-01_00:29:30 on domain   1:    1.05089 elapsed seconds
# Timing for main: time 2023-01-01_00:29:36 on domain   2:    0.12390 elapsed seconds
# Timing for main: time 2023-01-01_00:29:42 on domain   2:    0.12220 elapsed seconds
# Timing for main: time 2023-01-01_00:29:48 on domain   2:    0.11749 elapsed seconds
# Timing for main: time 2023-01-01_00:29:54 on domain   2:    0.11032 elapsed seconds
# Timing for main: time 2023-01-01_00:30:00 on domain   2:    0.10471 elapsed seconds
# Timing for main: time 2023-01-01_00:30:00 on domain   1:    0.90624 elapsed seconds
# Timing for main: time 2023-01-01_00:30:06 on domain   2:    1.55391 elapsed seconds
# Timing for main: time 2023-01-01_00:30:12 on domain   2:    0.10570 elapsed seconds
# Timing for main: time 2023-01-01_00:30:18 on domain   2:    0.10617 elapsed seconds
# Timing for main: time 2023-01-01_00:30:24 on domain   2:    0.10550 elapsed seconds
# Timing for main: time 2023-01-01_00:30:30 on domain   2:    0.10543 elapsed seconds
# Timing for main: time 2023-01-01_00:30:30 on domain   1:    3.68920 elapsed seconds
# Timing for main: time 2023-01-01_00:30:36 on domain   2:    0.11261 elapsed seconds
# Timing for main: time 2023-01-01_00:30:42 on domain   2:    0.10861 elapsed seconds
# Timing for main: time 2023-01-01_00:30:48 on domain   2:    0.10931 elapsed seconds
# Timing for main: time 2023-01-01_00:30:54 on domain   2:    0.11683 elapsed seconds
# Timing for main: time 2023-01-01_00:31:00 on domain   2:    0.10587 elapsed seconds
# Timing for main: time 2023-01-01_00:31:00 on domain   1:    0.85594 elapsed seconds
# Timing for main: time 2023-01-01_00:31:06 on domain   2:    0.10338 elapsed seconds
# Timing for main: time 2023-01-01_00:31:12 on domain   2:    0.10365 elapsed seconds
# Timing for main: time 2023-01-01_00:31:18 on domain   2:    0.11628 elapsed seconds
# Timing for main: time 2023-01-01_00:31:24 on domain   2:    0.11107 elapsed seconds
# Timing for main: time 2023-01-01_00:31:30 on domain   2:    0.11024 elapsed seconds
# Timing for main: time 2023-01-01_00:31:30 on domain   1:    0.83927 elapsed seconds
# Timing for main: time 2023-01-01_00:31:36 on domain   2:    0.10836 elapsed seconds
# Timing for main: time 2023-01-01_00:31:42 on domain   2:    0.11058 elapsed seconds
# Timing for main: time 2023-01-01_00:31:48 on domain   2:    0.10977 elapsed seconds
# Timing for main: time 2023-01-01_00:31:54 on domain   2:    0.10279 elapsed seconds
# Timing for main: time 2023-01-01_00:32:00 on domain   2:    0.10275 elapsed seconds
# Timing for main: time 2023-01-01_00:32:00 on domain   1:    0.83827 elapsed seconds
# Timing for main: time 2023-01-01_00:32:06 on domain   2:    0.10263 elapsed seconds
# Timing for main: time 2023-01-01_00:32:12 on domain   2:    0.10357 elapsed seconds
# Timing for main: time 2023-01-01_00:32:18 on domain   2:    0.10358 elapsed seconds
# Timing for main: time 2023-01-01_00:32:24 on domain   2:    0.16585 elapsed seconds
# Timing for main: time 2023-01-01_00:32:30 on domain   2:    0.10813 elapsed seconds
# Timing for main: time 2023-01-01_00:32:30 on domain   1:    0.88033 elapsed seconds
# Timing for main: time 2023-01-01_00:32:36 on domain   2:    0.10756 elapsed seconds
# Timing for main: time 2023-01-01_00:32:42 on domain   2:    0.11958 elapsed seconds
# Timing for main: time 2023-01-01_00:32:48 on domain   2:    0.10865 elapsed seconds
# Timing for main: time 2023-01-01_00:32:54 on domain   2:    0.11717 elapsed seconds
# Timing for main: time 2023-01-01_00:33:00 on domain   2:    0.10992 elapsed seconds
# Timing for main: time 2023-01-01_00:33:00 on domain   1:    0.86488 elapsed seconds
# Timing for main: time 2023-01-01_00:33:06 on domain   2:    0.10641 elapsed seconds
# Timing for main: time 2023-01-01_00:33:12 on domain   2:    0.11334 elapsed seconds
# Timing for main: time 2023-01-01_00:33:18 on domain   2:    0.10301 elapsed seconds
# Timing for main: time 2023-01-01_00:33:24 on domain   2:    0.10307 elapsed seconds
# Timing for main: time 2023-01-01_00:33:30 on domain   2:    0.11470 elapsed seconds
# Timing for main: time 2023-01-01_00:33:30 on domain   1:    0.83834 elapsed seconds
# Timing for main: time 2023-01-01_00:33:36 on domain   2:    0.10841 elapsed seconds
# Timing for main: time 2023-01-01_00:33:42 on domain   2:    0.10810 elapsed seconds
# Timing for main: time 2023-01-01_00:33:48 on domain   2:    0.14976 elapsed seconds
# Timing for main: time 2023-01-01_00:33:54 on domain   2:    0.79962 elapsed seconds
# Timing for main: time 2023-01-01_00:34:00 on domain   2:    0.13126 elapsed seconds
# Timing for main: time 2023-01-01_00:34:00 on domain   1:    1.71767 elapsed seconds
# Timing for main: time 2023-01-01_00:34:06 on domain   2:    0.10709 elapsed seconds
# Timing for main: time 2023-01-01_00:34:12 on domain   2:    0.11463 elapsed seconds
# Timing for main: time 2023-01-01_00:34:18 on domain   2:    0.11203 elapsed seconds
# Timing for main: time 2023-01-01_00:34:24 on domain   2:    0.11861 elapsed seconds
# Timing for main: time 2023-01-01_00:34:30 on domain   2:    0.11047 elapsed seconds
# Timing for main: time 2023-01-01_00:34:30 on domain   1:    0.90472 elapsed seconds
# Timing for main: time 2023-01-01_00:34:36 on domain   2:    0.10734 elapsed seconds
# Timing for main: time 2023-01-01_00:34:42 on domain   2:    0.10793 elapsed seconds
# Timing for main: time 2023-01-01_00:34:48 on domain   2:    0.10803 elapsed seconds
# Timing for main: time 2023-01-01_00:34:54 on domain   2:    0.10977 elapsed seconds
# Timing for main: time 2023-01-01_00:35:00 on domain   2:    0.10374 elapsed seconds
# Timing for main: time 2023-01-01_00:35:00 on domain   1:    0.83524 elapsed seconds
# Timing for main: time 2023-01-01_00:35:06 on domain   2:    0.10646 elapsed seconds
# Timing for main: time 2023-01-01_00:35:12 on domain   2:    0.10863 elapsed seconds
# Timing for main: time 2023-01-01_00:35:18 on domain   2:    0.10927 elapsed seconds
# Timing for main: time 2023-01-01_00:35:24 on domain   2:    0.12107 elapsed seconds
# Timing for main: time 2023-01-01_00:35:30 on domain   2:    0.11005 elapsed seconds
# Timing for main: time 2023-01-01_00:35:30 on domain   1:    0.85606 elapsed seconds
# Timing for main: time 2023-01-01_00:35:36 on domain   2:    0.10817 elapsed seconds
# Timing for main: time 2023-01-01_00:35:42 on domain   2:    0.10812 elapsed seconds
# Timing for main: time 2023-01-01_00:35:48 on domain   2:    0.10941 elapsed seconds
# Timing for main: time 2023-01-01_00:35:54 on domain   2:    0.11690 elapsed seconds
# Timing for main: time 2023-01-01_00:36:00 on domain   2:    0.12018 elapsed seconds
# Timing for main: time 2023-01-01_00:36:00 on domain   1:    0.87743 elapsed seconds
# Timing for main: time 2023-01-01_00:36:06 on domain   2:    0.10715 elapsed seconds
# Timing for main: time 2023-01-01_00:36:12 on domain   2:    0.10887 elapsed seconds
# Timing for main: time 2023-01-01_00:36:18 on domain   2:    0.10882 elapsed seconds
# Timing for main: time 2023-01-01_00:36:24 on domain   2:    0.11357 elapsed seconds
# Timing for main: time 2023-01-01_00:36:30 on domain   2:    0.10967 elapsed seconds
# Timing for main: time 2023-01-01_00:36:30 on domain   1:    0.85108 elapsed seconds
# Timing for main: time 2023-01-01_00:36:36 on domain   2:    0.10847 elapsed seconds
# Timing for main: time 2023-01-01_00:36:42 on domain   2:    0.10890 elapsed seconds
# Timing for main: time 2023-01-01_00:36:48 on domain   2:    0.10888 elapsed seconds
# Timing for main: time 2023-01-01_00:36:54 on domain   2:    0.11130 elapsed seconds
# Timing for main: time 2023-01-01_00:37:00 on domain   2:    0.10698 elapsed seconds
# Timing for main: time 2023-01-01_00:37:00 on domain   1:    0.84673 elapsed seconds
# Timing for main: time 2023-01-01_00:37:06 on domain   2:    0.11274 elapsed seconds
# Timing for main: time 2023-01-01_00:37:12 on domain   2:    0.12253 elapsed seconds
# Timing for main: time 2023-01-01_00:37:18 on domain   2:    0.10748 elapsed seconds
# Timing for main: time 2023-01-01_00:37:24 on domain   2:    0.10884 elapsed seconds
# Timing for main: time 2023-01-01_00:37:30 on domain   2:    0.23720 elapsed seconds
# Timing for main: time 2023-01-01_00:37:30 on domain   1:    1.03497 elapsed seconds
# Timing for main: time 2023-01-01_00:37:36 on domain   2:    0.10987 elapsed seconds
# Timing for main: time 2023-01-01_00:37:42 on domain   2:    0.11066 elapsed seconds
# Timing for main: time 2023-01-01_00:37:48 on domain   2:    0.11092 elapsed seconds
# Timing for main: time 2023-01-01_00:37:54 on domain   2:    0.10881 elapsed seconds
# Timing for main: time 2023-01-01_00:38:00 on domain   2:    0.10796 elapsed seconds
# Timing for main: time 2023-01-01_00:38:00 on domain   1:    0.98738 elapsed seconds
# ...
# Timing for main: time 2023-01-01_17:44:54 on domain   2:    0.12623 elapsed seconds
# Timing for main: time 2023-01-01_17:45:00 on domain   2:    0.11260 elapsed seconds
# Timing for main: time 2023-01-01_17:45:00 on domain   1:    0.95951 elapsed seconds
# Timing for main: time 2023-01-01_17:45:06 on domain   2:    0.64193 elapsed seconds
# Timing for main: time 2023-01-01_17:45:12 on domain   2:    0.11474 elapsed seconds
# Timing for main: time 2023-01-01_17:45:18 on domain   2:    0.12209 elapsed seconds
# Timing for main: time 2023-01-01_17:45:24 on domain   2:    0.11575 elapsed seconds
# Timing for main: time 2023-01-01_17:45:30 on domain   2:    0.11235 elapsed seconds
# Timing for main: time 2023-01-01_17:45:30 on domain   1:    1.95355 elapsed seconds
# Timing for main: time 2023-01-01_17:45:36 on domain   2:    0.11818 elapsed seconds
# Timing for main: time 2023-01-01_17:45:42 on domain   2:    0.14120 elapsed seconds
# Timing for main: time 2023-01-01_17:45:48 on domain   2:    0.12790 elapsed seconds
# Timing for main: time 2023-01-01_17:45:54 on domain   2:    0.12016 elapsed seconds
# Timing for main: time 2023-01-01_17:46:00 on domain   2:    0.12291 elapsed seconds
# Timing for main: time 2023-01-01_17:46:00 on domain   1:    0.95970 elapsed seconds
# Timing for main: time 2023-01-01_17:46:06 on domain   2:    0.15249 elapsed seconds
# Timing for main: time 2023-01-01_17:46:12 on domain   2:    0.18178 elapsed seconds
# Timing for main: time 2023-01-01_17:46:18 on domain   2:    0.12806 elapsed seconds
# Timing for main: time 2023-01-01_17:46:24 on domain   2:    0.12845 elapsed seconds
# Timing for main: time 2023-01-01_17:46:30 on domain   2:    0.13867 elapsed seconds
# Timing for main: time 2023-01-01_17:46:30 on domain   1:    1.11901 elapsed seconds
# Timing for main: time 2023-01-01_17:46:36 on domain   2:    0.12280 elapsed seconds
# Timing for main: time 2023-01-01_17:46:42 on domain   2:    0.12878 elapsed seconds
# Timing for main: time 2023-01-01_17:46:48 on domain   2:    0.12865 elapsed seconds
# Timing for main: time 2023-01-01_17:46:54 on domain   2:    0.13468 elapsed seconds
# Timing for main: time 2023-01-01_17:47:00 on domain   2:    0.12209 elapsed seconds
# Timing for main: time 2023-01-01_17:47:00 on domain   1:    1.03820 elapsed seconds
# Timing for main: time 2023-01-01_17:47:06 on domain   2:    0.13630 elapsed seconds
# Timing for main: time 2023-01-01_17:47:12 on domain   2:    0.13611 elapsed seconds
# Timing for main: time 2023-01-01_17:47:18 on domain   2:    0.13465 elapsed seconds
# Timing for main: time 2023-01-01_17:47:24 on domain   2:    0.11431 elapsed seconds
# Timing for main: time 2023-01-01_17:47:30 on domain   2:    0.11266 elapsed seconds
# Timing for main: time 2023-01-01_17:47:30 on domain   1:    1.00599 elapsed seconds
# Timing for main: time 2023-01-01_17:47:36 on domain   2:    0.10907 elapsed seconds
# Timing for main: time 2023-01-01_17:47:42 on domain   2:    0.11215 elapsed seconds
# Timing for main: time 2023-01-01_17:47:48 on domain   2:    0.11549 elapsed seconds
# Timing for main: time 2023-01-01_17:47:54 on domain   2:    0.11456 elapsed seconds
# Timing for main: time 2023-01-01_17:48:00 on domain   2:    0.11496 elapsed seconds
# Timing for main: time 2023-01-01_17:48:00 on domain   1:    0.88758 elapsed seconds
# Timing for main: time 2023-01-01_17:48:06 on domain   2:    0.11126 elapsed seconds
# Timing for main: time 2023-01-01_17:48:12 on domain   2:    0.11384 elapsed seconds
# Timing for main: time 2023-01-01_17:48:18 on domain   2:    0.11578 elapsed seconds
# Timing for main: time 2023-01-01_17:48:24 on domain   2:    0.11740 elapsed seconds
# Timing for main: time 2023-01-01_17:48:30 on domain   2:    0.11269 elapsed seconds
# Timing for main: time 2023-01-01_17:48:30 on domain   1:    0.89183 elapsed seconds
# Timing for main: time 2023-01-01_17:48:36 on domain   2:    0.11269 elapsed seconds
# Timing for main: time 2023-01-01_17:48:42 on domain   2:    0.12391 elapsed seconds
# Timing for main: time 2023-01-01_17:48:48 on domain   2:    0.10798 elapsed seconds
# Timing for main: time 2023-01-01_17:48:54 on domain   2:    0.10801 elapsed seconds
# Timing for main: time 2023-01-01_17:49:00 on domain   2:    0.11298 elapsed seconds
# Timing for main: time 2023-01-01_17:49:00 on domain   1:    0.89268 elapsed seconds
# Timing for main: time 2023-01-01_17:49:06 on domain   2:    0.12427 elapsed seconds
# Timing for main: time 2023-01-01_17:49:12 on domain   2:    0.13776 elapsed seconds
# Timing for main: time 2023-01-01_17:49:18 on domain   2:    0.11944 elapsed seconds
# Timing for main: time 2023-01-01_17:49:24 on domain   2:    0.11741 elapsed seconds
# Timing for main: time 2023-01-01_17:49:30 on domain   2:    0.11122 elapsed seconds
# Timing for main: time 2023-01-01_17:49:30 on domain   1:    0.94658 elapsed seconds
# Timing for main: time 2023-01-01_17:49:36 on domain   2:    0.24401 elapsed seconds
# Timing for main: time 2023-01-01_17:49:42 on domain   2:    0.13185 elapsed seconds
# Timing for main: time 2023-01-01_17:49:48 on domain   2:    0.12996 elapsed seconds
# Timing for main: time 2023-01-01_17:49:54 on domain   2:    0.11971 elapsed seconds
# Timing for main: time 2023-01-01_17:50:00 on domain   2:    0.11690 elapsed seconds
# Timing for main: time 2023-01-01_17:50:00 on domain   1:    1.06781 elapsed seconds
# Timing for main: time 2023-01-01_17:50:06 on domain   2:    0.11010 elapsed seconds
# Timing for main: time 2023-01-01_17:50:12 on domain   2:    0.11095 elapsed seconds
# Timing for main: time 2023-01-01_17:50:18 on domain   2:    0.11036 elapsed seconds
# Timing for main: time 2023-01-01_17:50:24 on domain   2:    0.10916 elapsed seconds
# Timing for main: time 2023-01-01_17:50:30 on domain   2:    0.10911 elapsed seconds
# Timing for main: time 2023-01-01_17:50:30 on domain   1:    0.87603 elapsed seconds
# Timing for main: time 2023-01-01_17:50:36 on domain   2:    0.10752 elapsed seconds
# Timing for main: time 2023-01-01_17:50:42 on domain   2:    0.11192 elapsed seconds
# Timing for main: time 2023-01-01_17:50:48 on domain   2:    0.11305 elapsed seconds
# Timing for main: time 2023-01-01_17:50:54 on domain   2:    0.12059 elapsed seconds
# Timing for main: time 2023-01-01_17:51:00 on domain   2:    0.12469 elapsed seconds
# Timing for main: time 2023-01-01_17:51:00 on domain   1:    0.90666 elapsed seconds
# Timing for main: time 2023-01-01_17:51:06 on domain   2:    0.10956 elapsed seconds
# Timing for main: time 2023-01-01_17:51:12 on domain   2:    0.10941 elapsed seconds
# Timing for main: time 2023-01-01_17:51:18 on domain   2:    0.10970 elapsed seconds
# Timing for main: time 2023-01-01_17:51:24 on domain   2:    0.12191 elapsed seconds
# Timing for main: time 2023-01-01_17:51:30 on domain   2:    0.11534 elapsed seconds
# Timing for main: time 2023-01-01_17:51:30 on domain   1:    0.89316 elapsed seconds
# Timing for main: time 2023-01-01_17:51:36 on domain   2:    0.11595 elapsed seconds
# Timing for main: time 2023-01-01_17:51:42 on domain   2:    0.13317 elapsed seconds
# Timing for main: time 2023-01-01_17:51:48 on domain   2:    0.11599 elapsed seconds
# Timing for main: time 2023-01-01_17:51:54 on domain   2:    0.11662 elapsed seconds
# Timing for main: time 2023-01-01_17:52:00 on domain   2:    0.11126 elapsed seconds
# Timing for main: time 2023-01-01_17:52:00 on domain   1:    0.91883 elapsed seconds
# Timing for main: time 2023-01-01_17:52:06 on domain   2:    0.11259 elapsed seconds
# Timing for main: time 2023-01-01_17:52:12 on domain   2:    0.11307 elapsed seconds
# Timing for main: time 2023-01-01_17:52:18 on domain   2:    0.11296 elapsed seconds
# Timing for main: time 2023-01-01_17:52:24 on domain   2:    0.11487 elapsed seconds
# Timing for main: time 2023-01-01_17:52:30 on domain   2:    0.10949 elapsed seconds
# Timing for main: time 2023-01-01_17:52:30 on domain   1:    0.89240 elapsed seconds
# Timing for main: time 2023-01-01_17:52:36 on domain   2:    0.10912 elapsed seconds
# Timing for main: time 2023-01-01_17:52:42 on domain   2:    0.10990 elapsed seconds
# Timing for main: time 2023-01-01_17:52:48 on domain   2:    0.10926 elapsed seconds
# Timing for main: time 2023-01-01_17:52:54 on domain   2:    0.11057 elapsed seconds
# Timing for main: time 2023-01-01_17:53:00 on domain   2:    0.11576 elapsed seconds
# Timing for main: time 2023-01-01_17:53:00 on domain   1:    0.87498 elapsed seconds
# Timing for main: time 2023-01-01_17:53:06 on domain   2:    0.11526 elapsed seconds
# Timing for main: time 2023-01-01_17:53:12 on domain   2:    0.11438 elapsed seconds
# Timing for main: time 2023-01-01_17:53:18 on domain   2:    0.10889 elapsed seconds
# Timing for main: time 2023-01-01_17:53:24 on domain   2:    0.11232 elapsed seconds
# Timing for main: time 2023-01-01_17:53:30 on domain   2:    0.11310 elapsed seconds
# Timing for main: time 2023-01-01_17:53:30 on domain   1:    0.90100 elapsed seconds
# Timing for main: time 2023-01-01_17:53:36 on domain   2:    0.11003 elapsed seconds
# Timing for main: time 2023-01-01_17:53:42 on domain   2:    0.11111 elapsed seconds
# Timing for main: time 2023-01-01_17:53:48 on domain   2:    0.11589 elapsed seconds
# Timing for main: time 2023-01-01_17:53:54 on domain   2:    0.11142 elapsed seconds
# Timing for main: time 2023-01-01_17:54:00 on domain   2:    0.10925 elapsed seconds
# Timing for main: time 2023-01-01_17:54:00 on domain   1:    0.88462 elapsed seconds
# Timing for main: time 2023-01-01_17:54:06 on domain   2:    0.11296 elapsed seconds
# Timing for main: time 2023-01-01_17:54:12 on domain   2:    0.11730 elapsed seconds
# Timing for main: time 2023-01-01_17:54:18 on domain   2:    0.11327 elapsed seconds
# Timing for main: time 2023-01-01_17:54:24 on domain   2:    0.11452 elapsed seconds
# Timing for main: time 2023-01-01_17:54:30 on domain   2:    0.11304 elapsed seconds
# Timing for main: time 2023-01-01_17:54:30 on domain   1:    0.89345 elapsed seconds
# Timing for main: time 2023-01-01_17:54:36 on domain   2:    0.11389 elapsed seconds
# Timing for main: time 2023-01-01_17:54:42 on domain   2:    0.12370 elapsed seconds
# Timing for main: time 2023-01-01_17:54:48 on domain   2:    0.12266 elapsed seconds
# Timing for main: time 2023-01-01_17:54:54 on domain   2:    0.10877 elapsed seconds
# Timing for main: time 2023-01-01_17:55:00 on domain   2:    0.10932 elapsed seconds
# Timing for main: time 2023-01-01_17:55:00 on domain   1:    0.90653 elapsed seconds
# Timing for main: time 2023-01-01_17:55:06 on domain   2:    0.11307 elapsed seconds
# Timing for main: time 2023-01-01_17:55:12 on domain   2:    0.10856 elapsed seconds
# Timing for main: time 2023-01-01_17:55:18 on domain   2:    0.10907 elapsed seconds
# Timing for main: time 2023-01-01_17:55:24 on domain   2:    0.10990 elapsed seconds
# Timing for main: time 2023-01-01_17:55:30 on domain   2:    0.11832 elapsed seconds
# Timing for main: time 2023-01-01_17:55:30 on domain   1:    0.87842 elapsed seconds
# Timing for main: time 2023-01-01_17:55:36 on domain   2:    0.11684 elapsed seconds
# Timing for main: time 2023-01-01_17:55:42 on domain   2:    0.11500 elapsed seconds
# Timing for main: time 2023-01-01_17:55:48 on domain   2:    0.11003 elapsed seconds
# Timing for main: time 2023-01-01_17:55:54 on domain   2:    0.10969 elapsed seconds
# Timing for main: time 2023-01-01_17:56:00 on domain   2:    0.11502 elapsed seconds
# Timing for main: time 2023-01-01_17:56:00 on domain   1:    0.89280 elapsed seconds
# Timing for main: time 2023-01-01_17:56:06 on domain   2:    0.11462 elapsed seconds
# Timing for main: time 2023-01-01_17:56:12 on domain   2:    0.11486 elapsed seconds
# Timing for main: time 2023-01-01_17:56:18 on domain   2:    0.10798 elapsed seconds
# Timing for main: time 2023-01-01_17:56:24 on domain   2:    0.10977 elapsed seconds
# Timing for main: time 2023-01-01_17:56:30 on domain   2:    0.10700 elapsed seconds
# Timing for main: time 2023-01-01_17:56:30 on domain   1:    0.88198 elapsed seconds
# Timing for main: time 2023-01-01_17:56:36 on domain   2:    0.10711 elapsed seconds
# Timing for main: time 2023-01-01_17:56:42 on domain   2:    0.10796 elapsed seconds
# Timing for main: time 2023-01-01_17:56:48 on domain   2:    0.11551 elapsed seconds
# Timing for main: time 2023-01-01_17:56:54 on domain   2:    0.11167 elapsed seconds
# Timing for main: time 2023-01-01_17:57:00 on domain   2:    0.11156 elapsed seconds
# Timing for main: time 2023-01-01_17:57:00 on domain   1:    0.87179 elapsed seconds
# Timing for main: time 2023-01-01_17:57:06 on domain   2:    0.16312 elapsed seconds
# Timing for main: time 2023-01-01_17:57:12 on domain   2:    0.17665 elapsed seconds
# Timing for main: time 2023-01-01_17:57:18 on domain   2:    0.12824 elapsed seconds
# Timing for main: time 2023-01-01_17:57:24 on domain   2:    0.13452 elapsed seconds
# Timing for main: time 2023-01-01_17:57:30 on domain   2:    0.17477 elapsed seconds
# Timing for main: time 2023-01-01_17:57:30 on domain   1:    1.10972 elapsed seconds
# Timing for main: time 2023-01-01_17:57:36 on domain   2:    0.12821 elapsed seconds
# Timing for main: time 2023-01-01_17:57:42 on domain   2:    0.12478 elapsed seconds
# Timing for main: time 2023-01-01_17:57:48 on domain   2:    0.13286 elapsed seconds
# Timing for main: time 2023-01-01_17:57:54 on domain   2:    0.14570 elapsed seconds
# Timing for main: time 2023-01-01_17:58:00 on domain   2:    0.12502 elapsed seconds
# Timing for main: time 2023-01-01_17:58:00 on domain   1:    1.02460 elapsed seconds
# Timing for main: time 2023-01-01_17:58:06 on domain   2:    0.12595 elapsed seconds
# Timing for main: time 2023-01-01_17:58:12 on domain   2:    0.15490 elapsed seconds
# Timing for main: time 2023-01-01_17:58:18 on domain   2:    0.14529 elapsed seconds
# Timing for main: time 2023-01-01_17:58:24 on domain   2:    0.14332 elapsed seconds
# Timing for main: time 2023-01-01_17:58:30 on domain   2:    0.14986 elapsed seconds
# Timing for main: time 2023-01-01_17:58:30 on domain   1:    1.07761 elapsed seconds
# Timing for main: time 2023-01-01_17:58:36 on domain   2:    0.12928 elapsed seconds
# Timing for main: time 2023-01-01_17:58:42 on domain   2:    0.13403 elapsed seconds
# Timing for main: time 2023-01-01_17:58:48 on domain   2:    0.13090 elapsed seconds
# Timing for main: time 2023-01-01_17:58:54 on domain   2:    0.12446 elapsed seconds
# Timing for main: time 2023-01-01_17:59:00 on domain   2:    0.13245 elapsed seconds
# Timing for main: time 2023-01-01_17:59:00 on domain   1:    1.00337 elapsed seconds
# Timing for main: time 2023-01-01_17:59:06 on domain   2:    0.11872 elapsed seconds
# Timing for main: time 2023-01-01_17:59:12 on domain   2:    0.12026 elapsed seconds
# Timing for main: time 2023-01-01_17:59:18 on domain   2:    0.11617 elapsed seconds
# Timing for main: time 2023-01-01_17:59:24 on domain   2:    0.12140 elapsed seconds
# Timing for main: time 2023-01-01_17:59:30 on domain   2:    0.11150 elapsed seconds
# Timing for main: time 2023-01-01_17:59:30 on domain   1:    0.93468 elapsed seconds
# Timing for main: time 2023-01-01_17:59:36 on domain   2:    0.14164 elapsed seconds
# Timing for main: time 2023-01-01_17:59:42 on domain   2:    0.14324 elapsed seconds
# Timing for main: time 2023-01-01_17:59:48 on domain   2:    0.12285 elapsed seconds
# Timing for main: time 2023-01-01_17:59:54 on domain   2:    0.12469 elapsed seconds
# Timing for main: time 2023-01-01_18:00:00 on domain   2:    0.11477 elapsed seconds
# Timing for Writing wrfout_d02_2023-01-01_18:00:00 for domain        2:    0.18312 elapsed seconds
# Timing for main: time 2023-01-01_18:00:00 on domain   1:    1.16030 elapsed seconds
#  mediation_integrate.G        1242 DATASET=HISTORY
#  mediation_integrate.G        1243  grid%id            2  grid%oid            2
# Timing for Writing wrfout_d01_2023-01-01_18:00:00 for domain        1:    0.20464 elapsed seconds
# d01 2023-01-01_18:00:00 wrf: SUCCESS COMPLETE WRF
# /Users/doan/Documents/GitHub/Pseudo-Global-Warming-Downscaling/03_WRF_run
#  mediation_integrate.G        1242 DATASET=HISTORY
#  mediation_integrate.G        1243  grid%id            1  grid%oid            2
# 0
